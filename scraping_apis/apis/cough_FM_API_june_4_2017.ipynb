# %% [markdown]
# # Last FM API (Music)
#
# Spotify's API is dead to us, so we're using Last.fm's - it's still music, just not as nice of an API.
#
# 1. Create an account at https://www.last.fm/api/
# 2. Create an "application" to get a key: https://www.last.fm/api/account/create
#     - It isn't a real application, it's just your project
#     - Name/description doesn't matter, ignore callback key and callback url
# 3. And save the API key that shows up on the next screen
#
# f700ab3104ce0a68942d14f72b4113bd
#
# You can find documentation at https://www.last.fm/api/
#
# The domain for the API is `http://ws.audioscrobbler.com`, so all of your endpoints will be connected to that. To test your API key, check the following URL in your browser: `http://ws.audioscrobbler.com/2.0/?method=artist.search&artist=cher&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json` (change the `XXXXXX` to be your API key, of course!).
#
# > Last.fm used to be called **AudioScrobbler**, which is why its URLs don't have "last.fm" in them.
# > While we're asking about URLs, notice that the API endpoints have a lot of `?` and `&` in them - these are key/value pairs, kind of like dictionaries, but for URLs instead of Python.

# %% [markdown]
# # FIRST: SETUP

# %% [markdown]
# ## 1) Import the libraries/packages you might need
#
# We need a library to read in the data for us! We don't like `urllib2`, so it must be something cooler and better.

# %%
# Import what you need here
import requests

# %% [markdown]
# ## 2) Save your API key
#
# Write your API key here so you don't forget it - it's the "api key" one, not the "shared secret" one

# %%
# f700ab3104ce0a68942d14f72b4113bd/

# %% [markdown]
# ## 3) A new function! Just run the code below. DO NOT EDIT IT.
#
# After you run this cell, you'll have a new function that you can use to display images.

# %%
import urllib
from IPython.display import display, Image
from IPython.core.display import HTML 

def display_image(url):
    response = urllib.request.urlopen(url).read()
    img = Image(response, width=200)
    display(img)

# %% [markdown]
# All you need to do to display an image is use `display_image` and send it a string, just like this:

# %%
display_image("https://lastfm-img2.akamaized.net/i/u/300x300/0fc7d7a1812dc79e9925d80382cde594.png")

# %% [markdown]
# # NOW: YOUR ASSIGNMENT

# %% [markdown]
# ## 1) Search for and print a list of 50 musicians with `lil` in their name, along with the number of listeners they have
#
# There are a lot of musicians with "Lil" in their name - it used to be all Lil Wayne and Lil Kim, but we live in a new world now!
#
# - *Tip: Remember, the domain for the API is `http://ws.audioscrobbler.com`*
# - *Tip: Make sure you ask the API for 50 musicians! This involves adding another parameter to the URL - notice they all have a `&` before them. [Read the documentation](http://www.last.fm/api/show/artist.search) to find the parameter's name.*
# - *Tip: When you are looking at any piece of data - is it a dictionary? Look at the keys! Is it a list? Look at the first element!*
# - *Tip: LOOK AT THE KEYS. and then the other keys and the other keys and the other keys. It's an ugly series of dictionaries!*

# %%
url = "http://ws.audioscrobbler.com/2.0/?method=artist.search&artist=lil&limit=50&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json"

# %%
response = requests.get(url)
print(response.text)
# Out:
# {"results":{"opensearch:Query":{"#text":"","role":"request","searchTerms":"lil","startPage":"1"},"opensearch:totalResults":"429473","opensearch:startIndex":"0","opensearch:itemsPerPage":"50","artistmatches":{"artist":[{"name":"Lil' Wayne","listeners":"3087331","mbid":"","url":"https://www.last.fm/music/Lil%27+Wayne","streamable":"0","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/0fc7d7a1812dc79e9925d80382cde594.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/0fc7d7a1812dc79e9925d80382cde594.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/0fc7d7a1812dc79e9925d80382cde594.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/0fc7d7a1812dc79e9925d80382cde594.png","size":"extralarge"},{"#text":"https://lastfm-img2.akamaized.net/i/u/0fc7d7a1812dc79e9925d80382cde594.png","size":"mega"}]},{"name":"Lily Allen","listeners":"2074715","mbid":"6e0c7c0e-cba5-4c2c-a652-38f71ef5785d","url":"https://www.last.fm/music/Lily+Allen","streamable":"0","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/780a6fd16c0e4fa849042f613eae7b1f.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/780a6fd16c0e4fa849042f613eae7b1f.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/780a6fd16c0e4fa849042f613eae7b1f.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/780a6fd16c0e4fa849042f613eae7b1f.png","size":"extralarge"},{"#text":"https://lastfm-img2.akamaized.net/i/u/780a6fd16c0e4fa849042f613eae7b1f.png","size":"mega"}]},{"name":"Lil B","listeners":"194162","mbid":"1550f952-c91b-40d7-9b4d-d26a259ee932","url":"https://www.last.fm/music/Lil+B","streamable":"0","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/0e88d9599c1249a4a63c76f7308066d2.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/0e88d9599c1249a4a63c76f7308066d2.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/0e88d9599c1249a4a63c76f7308066d2.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/0e88d9599c1249a4a63c76f7308066d2.png","size":"extralarge"},{"#text":"https://lastfm-img2.akamaized.net/i/u/0e88d9599c1249a4a63c76f7308066d2.png","size":"mega"}]},{"name":"Lilly Wood & The Prick","listeners":"360140","mbid":"1b72331b-3a97-4981-a81c-eeee9c275d28","url":"https://www.last.fm/music/Lilly+Wood+&+The+Prick","streamable":"0","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/373db6ff849842f8c2ad2bd62a4af922.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/373db6ff849842f8c2ad2bd62a4af922.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/373db6ff849842f8c2ad2bd62a4af922.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/373db6ff849842f8c2ad2bd62a4af922.png","size":"extralarge"},{"#text":"https://lastfm-img2.akamaized.net/i/u/373db6ff849842f8c2ad2bd62a4af922.png","size":"mega"}]},{"name":"LIL UZI VERT","listeners":"90661","mbid":"","url":"https://www.last.fm/music/LIL+UZI+VERT","streamable":"0","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/7e0279fd3672976c6a604dffb8978e0b.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/7e0279fd3672976c6a604dffb8978e0b.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/7e0279fd3672976c6a604dffb8978e0b.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/7e0279fd3672976c6a604dffb8978e0b.png","size":"extralarge"},{"#text":"https://lastfm-img2.akamaized.net/i/u/7e0279fd3672976c6a604dffb8978e0b.png","size":"mega"}]},{"name":"Lil Ugly Mane","listeners":"31984","mbid":"5f1adfe1-4d07-4141-b181-79e5d379d539","url":"https://www.last.fm/music/Lil+Ugly+Mane","streamable":"0","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/e3b94d475d5e4d9eac268dadc601e135.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/e3b94d475d5e4d9eac268dadc6 ...

# %%
print(response.json())
data = response.json()
# Out:
# {'results': {'opensearch:Query': {'#text': '', 'role': 'request', 'searchTerms': 'lil', 'startPage': '1'}, 'opensearch:totalResults': '429473', 'opensearch:startIndex': '0', 'opensearch:itemsPerPage': '50', 'artistmatches': {'artist': [{'name': "Lil' Wayne", 'listeners': '3087331', 'mbid': '', 'url': 'https://www.last.fm/music/Lil%27+Wayne', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/0fc7d7a1812dc79e9925d80382cde594.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/0fc7d7a1812dc79e9925d80382cde594.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/0fc7d7a1812dc79e9925d80382cde594.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/0fc7d7a1812dc79e9925d80382cde594.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/0fc7d7a1812dc79e9925d80382cde594.png', 'size': 'mega'}]}, {'name': 'Lily Allen', 'listeners': '2074715', 'mbid': '6e0c7c0e-cba5-4c2c-a652-38f71ef5785d', 'url': 'https://www.last.fm/music/Lily+Allen', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/780a6fd16c0e4fa849042f613eae7b1f.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/780a6fd16c0e4fa849042f613eae7b1f.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/780a6fd16c0e4fa849042f613eae7b1f.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/780a6fd16c0e4fa849042f613eae7b1f.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/780a6fd16c0e4fa849042f613eae7b1f.png', 'size': 'mega'}]}, {'name': 'Lil B', 'listeners': '194162', 'mbid': '1550f952-c91b-40d7-9b4d-d26a259ee932', 'url': 'https://www.last.fm/music/Lil+B', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/0e88d9599c1249a4a63c76f7308066d2.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/0e88d9599c1249a4a63c76f7308066d2.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/0e88d9599c1249a4a63c76f7308066d2.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/0e88d9599c1249a4a63c76f7308066d2.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/0e88d9599c1249a4a63c76f7308066d2.png', 'size': 'mega'}]}, {'name': 'Lilly Wood & The Prick', 'listeners': '360140', 'mbid': '1b72331b-3a97-4981-a81c-eeee9c275d28', 'url': 'https://www.last.fm/music/Lilly+Wood+&+The+Prick', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/373db6ff849842f8c2ad2bd62a4af922.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/373db6ff849842f8c2ad2bd62a4af922.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/373db6ff849842f8c2ad2bd62a4af922.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/373db6ff849842f8c2ad2bd62a4af922.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/373db6ff849842f8c2ad2bd62a4af922.png', 'size': 'mega'}]}, {'name': 'LIL UZI VERT', 'listeners': '90661', 'mbid': '', 'url': 'https://www.last.fm/music/LIL+UZI+VERT', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/7e0279fd3672976c6a604dffb8978e0b.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/7e0279fd3672976c6a604dffb8978e0b.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/7e0279fd3672976c6a604dffb8978e0b.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/7e0279fd3672976c6a604dffb8978e0b.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/7e0279fd3672976c6a604dffb8978e0b.png', 'size': 'mega'}]}, {'name': 'Lil Ugly Mane', 'listeners': '31984', 'mbid': '5f1adfe1-4d07-4141-b181-79e5d379d539', 'url': 'https://www.last.fm/music/Lil+Ugly+Mane', 'streamable': '0', 'image': [ ...

# %%
print(type(data))
print(data.keys())
# Out:
# <class 'dict'>
# dict_keys(['results'])

# %%
print(data['results'])
results = data['results']
print(type(results))
# Out:
# {'opensearch:Query': {'#text': '', 'role': 'request', 'searchTerms': 'lil', 'startPage': '1'}, 'opensearch:totalResults': '429473', 'opensearch:startIndex': '0', 'opensearch:itemsPerPage': '50', 'artistmatches': {'artist': [{'name': "Lil' Wayne", 'listeners': '3087331', 'mbid': '', 'url': 'https://www.last.fm/music/Lil%27+Wayne', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/0fc7d7a1812dc79e9925d80382cde594.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/0fc7d7a1812dc79e9925d80382cde594.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/0fc7d7a1812dc79e9925d80382cde594.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/0fc7d7a1812dc79e9925d80382cde594.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/0fc7d7a1812dc79e9925d80382cde594.png', 'size': 'mega'}]}, {'name': 'Lily Allen', 'listeners': '2074715', 'mbid': '6e0c7c0e-cba5-4c2c-a652-38f71ef5785d', 'url': 'https://www.last.fm/music/Lily+Allen', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/780a6fd16c0e4fa849042f613eae7b1f.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/780a6fd16c0e4fa849042f613eae7b1f.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/780a6fd16c0e4fa849042f613eae7b1f.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/780a6fd16c0e4fa849042f613eae7b1f.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/780a6fd16c0e4fa849042f613eae7b1f.png', 'size': 'mega'}]}, {'name': 'Lil B', 'listeners': '194162', 'mbid': '1550f952-c91b-40d7-9b4d-d26a259ee932', 'url': 'https://www.last.fm/music/Lil+B', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/0e88d9599c1249a4a63c76f7308066d2.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/0e88d9599c1249a4a63c76f7308066d2.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/0e88d9599c1249a4a63c76f7308066d2.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/0e88d9599c1249a4a63c76f7308066d2.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/0e88d9599c1249a4a63c76f7308066d2.png', 'size': 'mega'}]}, {'name': 'Lilly Wood & The Prick', 'listeners': '360140', 'mbid': '1b72331b-3a97-4981-a81c-eeee9c275d28', 'url': 'https://www.last.fm/music/Lilly+Wood+&+The+Prick', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/373db6ff849842f8c2ad2bd62a4af922.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/373db6ff849842f8c2ad2bd62a4af922.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/373db6ff849842f8c2ad2bd62a4af922.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/373db6ff849842f8c2ad2bd62a4af922.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/373db6ff849842f8c2ad2bd62a4af922.png', 'size': 'mega'}]}, {'name': 'LIL UZI VERT', 'listeners': '90661', 'mbid': '', 'url': 'https://www.last.fm/music/LIL+UZI+VERT', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/7e0279fd3672976c6a604dffb8978e0b.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/7e0279fd3672976c6a604dffb8978e0b.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/7e0279fd3672976c6a604dffb8978e0b.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/7e0279fd3672976c6a604dffb8978e0b.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/7e0279fd3672976c6a604dffb8978e0b.png', 'size': 'mega'}]}, {'name': 'Lil Ugly Mane', 'listeners': '31984', 'mbid': '5f1adfe1-4d07-4141-b181-79e5d379d539', 'url': 'https://www.last.fm/music/Lil+Ugly+Mane', 'streamable': '0', 'image': [{'#text': 'h ...
# <class 'dict'>

# %%
print(results.keys())
results['artistmatches']
# Out:
# dict_keys(['opensearch:Query', 'opensearch:totalResults', 'opensearch:startIndex', 'opensearch:itemsPerPage', 'artistmatches', '@attr'])
# {'artist': [{'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/0fc7d7a1812dc79e9925d80382cde594.png',
#      'size': 'small'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/0fc7d7a1812dc79e9925d80382cde594.png',
#      'size': 'medium'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/0fc7d7a1812dc79e9925d80382cde594.png',
#      'size': 'large'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/0fc7d7a1812dc79e9925d80382cde594.png',
#      'size': 'extralarge'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/0fc7d7a1812dc79e9925d80382cde594.png',
#      'size': 'mega'}],
#    'listeners': '3087331',
#    'mbid': '',
#    'name': "Lil' Wayne",
#    'streamable': '0',
#    'url': 'https://www.last.fm/music/Lil%27+Wayne'},
#   {'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/780a6fd16c0e4fa849042f613eae7b1f.png',
#      'size': 'small'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/780a6fd16c0e4fa849042f613eae7b1f.png',
#      'size': 'medium'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/780a6fd16c0e4fa849042f613eae7b1f.png',
#      'size': 'large'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/780a6fd16c0e4fa849042f613eae7b1f.png',
#      'size': 'extralarge'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/780a6fd16c0e4fa849042f613eae7b1f.png',
#      'size': 'mega'}],
#    'listeners': '2074715',
#    'mbid': '6e0c7c0e-cba5-4c2c-a652-38f71ef5785d',
#    'name': 'Lily Allen',
#    'streamable': '0',
#    'url': 'https://www.last.fm/music/Lily+Allen'},
#   {'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/0e88d9599c1249a4a63c76f7308066d2.png',
#      'size': 'small'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/0e88d9599c1249a4a63c76f7308066d2.png',
#      'size': 'medium'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/0e88d9599c1249a4a63c76f7308066d2.png',
#      'size': 'large'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/0e88d9599c1249a4a63c76f7308066d2.png',
#      'size': 'extralarge'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/0e88d9599c1249a4a63c76f7308066d2.png',
#      'size': 'mega'}],
#    'listeners': '194162',
#    'mbid': '1550f952-c91b-40d7-9b4d-d26a259ee932',
#    'name': 'Lil B',
#    'streamable': '0',
#    'url': 'https://www.last.fm/music/Lil+B'},
#   {'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/373db6ff849842f8c2ad2bd62a4af922.png',
#      'size': 'small'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/373db6ff849842f8c2ad2bd62a4af922.png',
#      'size': 'medium'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/373db6ff849842f8c2ad2bd62a4af922.png',
#      'size': 'large'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/373db6ff849842f8c2ad2bd62a4af922.png',
#      'size': 'extralarge'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/373db6ff849842f8c2ad2bd62a4af922.png',
#      'size': 'mega'}],
#    'listeners': '360140',
#    'mbid': '1b72331b-3a97-4981-a81c-eeee9c275d28',
#    'name': 'Lilly Wood & The Prick',
#    'streamable': '0',
#    'url': 'https://www.last.fm/music/Lilly+Wood+&+The+Prick'},
#   {'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/7e0279fd3672976c6a604dffb8978e0b.png',
#      'size': 'small'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/7e0279fd3672976c6a604dffb8978e0b.png',
#      'size': 'medium'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/7e0279fd3672976c6a604dffb8978e0b.png',
#      'size': 'large'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/7e0279fd3672976c6a604dffb8978e0b.png',
#      'size': 'extralarge'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/7e0279fd3672976c6a604dffb8978e0b.png',
#      'size': 'mega'}],
#    'listeners': '90661',
#    'mbid': '',
#    'name': 'LIL UZI VERT',
#    'streamable': '0',
#    'url': 'https://www.last.fm/music/LIL+UZI+VERT'},
#   {'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/e3b94d475d5e4d9eac268dadc601e135.png',
#      'size': 'small'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/e3b94d475d5e4d9eac268dadc601e135.png',
#      'size': 'medium'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/e3b94d475d5e4d9eac268dadc601e135.png',
#      'size': 'large'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/e3b94d475d5e4d9eac268dadc601e135.png',
#      'size': 'extralarge'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/e3b94d475d5e4d9eac268dadc601e135.png',
#      'size': 'mega'}],
#    'listeners': '31984',
#    'mbid': '5f1adfe1-4d07-4141-b181-79e5d379d539',
#    'name': 'Lil Ugly Mane',
#    'streamable': '0',
#    'url': 'https://www.last.fm/music/Lil+Ugly+Mane'},
#   {'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/8e5029ce3e2b4998810e1234365134e8.png',
#      'size': 'small'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/8e5029ce3e2b4998810e1234365134e8.png',
#      'size': 'medium'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/

#    'streamable': '0',
#    'url': 'https://www.last.fm/music/Lil+Bibby'},
#   {'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/89e967ab1e044449c48b0a97998e2aea.png',
#      'size': 'small'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/89e967ab1e044449c48b0a97998e2aea.png',
#      'size': 'medium'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/89e967ab1e044449c48b0a97998e2aea.png',
#      'size': 'large'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/89e967ab1e044449c48b0a97998e2aea.png',
#      'size': 'extralarge'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/89e967ab1e044449c48b0a97998e2aea.png',
#      'size': 'mega'}],
#    'listeners': '156123',
#    'mbid': '31445b1e-96f3-4c7f-84ec-dd02e647e690',
#    'name': 'DJ Snake & Lil Jon',
#    'streamable': '0',
#    'url': 'https://www.last.fm/music/DJ+Snake+&+Lil+Jon'},
#   {'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/9ee5958e719147a8870d3512935be09e.png',
#      'size': 'small'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/9ee5958e719147a8870d3512935be09e.png',
#      'size': 'medium'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/9ee5958e719147a8870d3512935be09e.png',
#      'size': 'large'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/9ee5958e719147a8870d3512935be09e.png',
#      'size': 'extralarge'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/9ee5958e719147a8870d3512935be09e.png',
#      'size': 'mega'}],
#    'listeners': '64376',
#    'mbid': '251541e9-4212-4350-99f0-d347a055cda6',
#    'name': 'Lil Keke',
#    'streamable': '0',
#    'url': 'https://www.last.fm/music/Lil+Keke'},
#   {'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/7aefaa4ad58f4b60e38c2207060d7b99.png',
#      'size': 'small'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/7aefaa4ad58f4b60e38c2207060d7b99.png',
#      'size': 'medium'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/7aefaa4ad58f4b60e38c2207060d7b99.png',
#      'size': 'large'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/7aefaa4ad58f4b60e38c2207060d7b99.png',
#      'size': 'extralarge'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/7aefaa4ad58f4b60e38c2207060d7b99.png',
#      'size': 'mega'}],
#    'listeners': '11773',
#    'mbid': '39fbfa96-5626-4d23-81f4-fe1676615680',
#    'name': 'Lilly Hates Roses',
#    'streamable': '0',
#    'url': 'https://www.last.fm/music/Lilly+Hates+Roses'},
#   {'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/54daf0caaeee498c821730d0efbe993f.png',
#      'size': 'small'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/54daf0caaeee498c821730d0efbe993f.png',
#      'size': 'medium'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/54daf0caaeee498c821730d0efbe993f.png',
#      'size': 'large'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/54daf0caaeee498c821730d0efbe993f.png',
#      'size': 'extralarge'},
#     {'#text': 'https://lastfm-img2.akamaized.net/i/u/54daf0caaeee498c821730d0efbe993f.png',
#      'size': 'mega'}],
#    'listeners': '83007',
#    'mbid': '',
#    'name': "Lil' Mo",
#    'streamable': '0',
#    'url': 'https://www.last.fm/music/Lil%27+Mo'}]}

# %%
artistmatches = results['artistmatches']
print(type(artistmatches))
print(artistmatches.keys())
print(artistmatches['artist'])
# Out:
# <class 'dict'>
# dict_keys(['artist'])
# [{'name': "Lil' Wayne", 'listeners': '3087331', 'mbid': '', 'url': 'https://www.last.fm/music/Lil%27+Wayne', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/0fc7d7a1812dc79e9925d80382cde594.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/0fc7d7a1812dc79e9925d80382cde594.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/0fc7d7a1812dc79e9925d80382cde594.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/0fc7d7a1812dc79e9925d80382cde594.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/0fc7d7a1812dc79e9925d80382cde594.png', 'size': 'mega'}]}, {'name': 'Lily Allen', 'listeners': '2074715', 'mbid': '6e0c7c0e-cba5-4c2c-a652-38f71ef5785d', 'url': 'https://www.last.fm/music/Lily+Allen', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/780a6fd16c0e4fa849042f613eae7b1f.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/780a6fd16c0e4fa849042f613eae7b1f.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/780a6fd16c0e4fa849042f613eae7b1f.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/780a6fd16c0e4fa849042f613eae7b1f.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/780a6fd16c0e4fa849042f613eae7b1f.png', 'size': 'mega'}]}, {'name': 'Lil B', 'listeners': '194162', 'mbid': '1550f952-c91b-40d7-9b4d-d26a259ee932', 'url': 'https://www.last.fm/music/Lil+B', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/0e88d9599c1249a4a63c76f7308066d2.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/0e88d9599c1249a4a63c76f7308066d2.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/0e88d9599c1249a4a63c76f7308066d2.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/0e88d9599c1249a4a63c76f7308066d2.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/0e88d9599c1249a4a63c76f7308066d2.png', 'size': 'mega'}]}, {'name': 'Lilly Wood & The Prick', 'listeners': '360140', 'mbid': '1b72331b-3a97-4981-a81c-eeee9c275d28', 'url': 'https://www.last.fm/music/Lilly+Wood+&+The+Prick', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/373db6ff849842f8c2ad2bd62a4af922.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/373db6ff849842f8c2ad2bd62a4af922.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/373db6ff849842f8c2ad2bd62a4af922.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/373db6ff849842f8c2ad2bd62a4af922.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/373db6ff849842f8c2ad2bd62a4af922.png', 'size': 'mega'}]}, {'name': 'LIL UZI VERT', 'listeners': '90661', 'mbid': '', 'url': 'https://www.last.fm/music/LIL+UZI+VERT', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/7e0279fd3672976c6a604dffb8978e0b.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/7e0279fd3672976c6a604dffb8978e0b.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/7e0279fd3672976c6a604dffb8978e0b.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/7e0279fd3672976c6a604dffb8978e0b.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/7e0279fd3672976c6a604dffb8978e0b.png', 'size': 'mega'}]}, {'name': 'Lil Ugly Mane', 'listeners': '31984', 'mbid': '5f1adfe1-4d07-4141-b181-79e5d379d539', 'url': 'https://www.last.fm/music/Lil+Ugly+Mane', 'streamable': '0', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/e3b94d475d5e4d9eac268dadc601e135.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/e3b94d475d5e4d9eac268dadc601e135.png', 'size': 'medium'}, {'#text': 'htt ...

# %%
artist = artistmatches['artist']
print(type(artist))
for each_element in artist:
    print(each_element['name'], "has", each_element['listeners'], "listeners.")
# Out:
# <class 'list'>
# Lil' Wayne has 3087331 listeners.
# Lily Allen has 2074715 listeners.
# Lil B has 194162 listeners.
# Lilly Wood & The Prick has 360140 listeners.
# LIL UZI VERT has 90661 listeners.
# Lil Ugly Mane has 31984 listeners.
# Lil Jon has 581672 listeners.
# Lil' Kim has 431471 listeners.
# Lil Jon & The East Side Boyz has 486926 listeners.
# Lil Yachty has 60683 listeners.
# Lil Boosie has 420366 listeners.
# Lila Downs has 155396 listeners.
# Lil Dicky has 79146 listeners.
# The Tiger Lillies has 106961 listeners.
# Lil Wyte has 255207 listeners.
# Birdman & Lil' Wayne has 587430 listeners.
# Lil' Flip has 324573 listeners.
# Lily & Madeleine has 111135 listeners.
# Spangle call Lilli line has 28726 listeners.
# Lil Durk has 49562 listeners.
# Lillasyster has 47289 listeners.
# Lilu has 35892 listeners.
# Lil' Scrappy has 257909 listeners.
# Lilys has 54248 listeners.
# The Lillingtons has 32096 listeners.
# LIL PEEP has 9073 listeners.
# Leila has 52341 listeners.
# Lil Mama has 150562 listeners.
# Lillix has 99361 listeners.
# Lily Chou-Chou has 29137 listeners.
# Liliput has 52113 listeners.
# Lil' Kleine has 32165 listeners.
# Amelia Lily has 60891 listeners.
# Mashrou' Leila has 17457 listeners.
# Lil Twist has 236684 listeners.
# Lilly Wood & The Prick And Robin Schulz has 61494 listeners.
# Lillies and Remains has 5653 listeners.
# Lil Rob has 95134 listeners.
# Lil Silva has 65561 listeners.
# Lil Scrappy has 99390 listeners.
# Lilium has 33047 listeners.
# Lilacs & Champagne has 24230 listeners.
# Lil Debbie has 15982 listeners.
# Lil Herb has 9192 listeners.
# Lil' Keke has 93440 listeners.
# Lil Bibby has 11959 listeners.
# DJ Snake & Lil Jon has 156123 listeners.
# Lil Keke has 64376 listeners.
# Lilly Hates Roses has 11773 listeners.
# Lil' Mo has 83007 listeners.

# %%
artist = artistmatches['artist']
print(type(artist))
for each_element in artist:
    print(each_element['name'], "has", each_element['listeners'], "listeners.")
# Out:
# <class 'list'>
# Lil' Wayne has 3087331 listeners.
# Lily Allen has 2074715 listeners.
# Lil B has 194162 listeners.
# Lilly Wood & The Prick has 360140 listeners.
# LIL UZI VERT has 90661 listeners.
# Lil Ugly Mane has 31984 listeners.
# Lil Jon has 581672 listeners.
# Lil' Kim has 431471 listeners.
# Lil Jon & The East Side Boyz has 486926 listeners.
# Lil Yachty has 60683 listeners.
# Lil Boosie has 420366 listeners.
# Lila Downs has 155396 listeners.
# Lil Dicky has 79146 listeners.
# The Tiger Lillies has 106961 listeners.
# Lil Wyte has 255207 listeners.
# Birdman & Lil' Wayne has 587430 listeners.
# Lil' Flip has 324573 listeners.
# Lily & Madeleine has 111135 listeners.
# Spangle call Lilli line has 28726 listeners.
# Lil Durk has 49562 listeners.
# Lillasyster has 47289 listeners.
# Lilu has 35892 listeners.
# Lil' Scrappy has 257909 listeners.
# Lilys has 54248 listeners.
# The Lillingtons has 32096 listeners.
# LIL PEEP has 9073 listeners.
# Leila has 52341 listeners.
# Lil Mama has 150562 listeners.
# Lillix has 99361 listeners.
# Lily Chou-Chou has 29137 listeners.
# Liliput has 52113 listeners.
# Lil' Kleine has 32165 listeners.
# Amelia Lily has 60891 listeners.
# Mashrou' Leila has 17457 listeners.
# Lil Twist has 236684 listeners.
# Lilly Wood & The Prick And Robin Schulz has 61494 listeners.
# Lillies and Remains has 5653 listeners.
# Lil Rob has 95134 listeners.
# Lil Silva has 65561 listeners.
# Lil Scrappy has 99390 listeners.
# Lilium has 33047 listeners.
# Lilacs & Champagne has 24230 listeners.
# Lil Debbie has 15982 listeners.
# Lil Herb has 9192 listeners.
# Lil' Keke has 93440 listeners.
# Lil Bibby has 11959 listeners.
# DJ Snake & Lil Jon has 156123 listeners.
# Lil Keke has 64376 listeners.
# Lilly Hates Roses has 11773 listeners.
# Lil' Mo has 83007 listeners.

# %% [markdown]
# Your results should begin something like this:
#
# ```
# Lil' Wayne has 3086628 listeners
# Lily Allen has 2074266 listeners
# Lil B has 194116 listeners
# Lilly Wood & The Prick has 359886 listeners
# Lil Ugly Mane has 31955 listeners
# LIL UZI VERT has 88517 listeners
# ```

# %% [markdown]
# ## 2) How many listeners does your list have in total?
#
# The answer should be roughly **11,500,000**. If it's closer to **10,000,000** make sure you have 50 artists instead of 30 artists.
#
# - *Tip: What's the data type of the `listeners` count? It's going to cause a problem!*
# - *Tip: If you were crazy you could use sum and a list comprehension. But you really don't have to!*

# %%
listeners_count = 0
for each_element in artist:
    listeners_count = int(each_element['listeners']) + listeners_count
    print("There are", listeners_count, "listeners total.")
# Out:
# There are 3087331 listeners total.
# There are 5162046 listeners total.
# There are 5356208 listeners total.
# There are 5716348 listeners total.
# There are 5807009 listeners total.
# There are 5838993 listeners total.
# There are 6420665 listeners total.
# There are 6852136 listeners total.
# There are 7339062 listeners total.
# There are 7399745 listeners total.
# There are 7820111 listeners total.
# There are 7975507 listeners total.
# There are 8054653 listeners total.
# There are 8161614 listeners total.
# There are 8416821 listeners total.
# There are 9004251 listeners total.
# There are 9328824 listeners total.
# There are 9439959 listeners total.
# There are 9468685 listeners total.
# There are 9518247 listeners total.
# There are 9565536 listeners total.
# There are 9601428 listeners total.
# There are 9859337 listeners total.
# There are 9913585 listeners total.
# There are 9945681 listeners total.
# There are 9954754 listeners total.
# There are 10007095 listeners total.
# There are 10157657 listeners total.
# There are 10257018 listeners total.
# There are 10286155 listeners total.
# There are 10338268 listeners total.
# There are 10370433 listeners total.
# There are 10431324 listeners total.
# There are 10448781 listeners total.
# There are 10685465 listeners total.
# There are 10746959 listeners total.
# There are 10752612 listeners total.
# There are 10847746 listeners total.
# There are 10913307 listeners total.
# There are 11012697 listeners total.
# There are 11045744 listeners total.
# There are 11069974 listeners total.
# There are 11085956 listeners total.
# There are 11095148 listeners total.
# There are 11188588 listeners total.
# There are 11200547 listeners total.
# There are 11356670 listeners total.
# There are 11421046 listeners total.
# There are 11432819 listeners total.
# There are 11515826 listeners total.

# %%
#how to limit it to only the last one?

# %% [markdown]
# ## 3) Show each artist's name and extra-large image
#
# Because you ran the code in setup, you now have a function called `display_image` that you can use to display an image if you give it a URL as a string. For example, I have this image and want to display it. I just send a string URL to the `display_image` method.

# %%
display_image("https://lastfm-img2.akamaized.net/i/u/300x300/0fc7d7a1812dc79e9925d80382cde594.png")

# %% [markdown]
# Each artist **has a list of images of different sizes**. We're interested in the second-to-last one, where `size` is `extralarge`. Print their name and use `display_image` to display their extra-large image.
#
# - *Tip: The URL should look like this: `https://lastfm-img2.akamaized.net/i/u/300x300/0fc7d7a1812dc79e9925d80382cde594.png`*
# - *Tip: You can always assume it's the second to the last, or assume it's `extralarge`, or whatever you want to do to find it.*
# - *Tip: Make sure the URL is correct before you try to display it.*

# %%
display_image("https://lastfm-img2.akamaized.net/i/u/300x300/7e0279fd3672976c6a604dffb8978e0b.png")

# %% [markdown]
# ## 4) Find Lil Jon's `mbid` (or anyone else's!).
#
# Oftentimes in an API, you can do a few things: you can **search** for items, and you can **see more information** about items. To find more information about the item, you need to use their **unique id**. In this dataset, it's called an `mbid` (MusicBrainz, I think - another company associated with last.fm!).
#
# Go through the artists and print their **name and mbid**. Find Lil Jon's `mbid`. I *wanted* Lil Uzi Vert's, but for some reason it isn't there. Then I wanted us to look at Lily Allen's, but I just couldn't bring myself to do that. If you'd rather do someone else, go for it.

# %%
artist = artistmatches['artist']
print(type(artist))
for each_element in artist:
    print("Artist", each_element['name'], "has the mbid", each_element['mbid'])
    print("-------------------------------------------------------------")
# Out:
# <class 'list'>
# Artist Lil' Wayne has the mbid
# -------------------------------------------------------------
# Artist Lily Allen has the mbid 6e0c7c0e-cba5-4c2c-a652-38f71ef5785d
# -------------------------------------------------------------
# Artist Lil B has the mbid 1550f952-c91b-40d7-9b4d-d26a259ee932
# -------------------------------------------------------------
# Artist Lilly Wood & The Prick has the mbid 1b72331b-3a97-4981-a81c-eeee9c275d28
# -------------------------------------------------------------
# Artist LIL UZI VERT has the mbid
# -------------------------------------------------------------
# Artist Lil Ugly Mane has the mbid 5f1adfe1-4d07-4141-b181-79e5d379d539
# -------------------------------------------------------------
# Artist Lil Jon has the mbid a95384b1-6aec-468c-ae0d-8c6daf87c4c2
# -------------------------------------------------------------
# Artist Lil' Kim has the mbid bc1b5c95-e6d6-46b5-957a-5e8908b02c1e
# -------------------------------------------------------------
# Artist Lil Jon & The East Side Boyz has the mbid 243c6f61-d83b-4459-bebd-5899df0da111
# -------------------------------------------------------------
# Artist Lil Yachty has the mbid
# -------------------------------------------------------------
# Artist Lil Boosie has the mbid 8ba17cf6-bec2-4ae4-9820-b1cda47adc08
# -------------------------------------------------------------
# Artist Lila Downs has the mbid ad29ae1c-2eda-4071-9dc8-31910e7e546c
# -------------------------------------------------------------
# Artist Lil Dicky has the mbid 3268f062-6e76-480a-a384-e1dd2a276afb
# -------------------------------------------------------------
# Artist The Tiger Lillies has the mbid 3ad4f6ec-253f-4050-8849-ca26266edfb8
# -------------------------------------------------------------
# Artist Lil Wyte has the mbid 9b5ce0c1-1bc0-4ea2-a8d3-f5ee7af9eda8
# -------------------------------------------------------------
# Artist Birdman & Lil' Wayne has the mbid
# -------------------------------------------------------------
# Artist Lil' Flip has the mbid 981d39fc-bd00-4cc6-ac67-6410f8b89098
# -------------------------------------------------------------
# Artist Lily & Madeleine has the mbid b89f4c50-72f5-48ce-b08c-a643b191b24f
# -------------------------------------------------------------
# Artist Spangle call Lilli line has the mbid bc21df5c-3d79-479b-b638-8ddb5ecea403
# -------------------------------------------------------------
# Artist Lil Durk has the mbid c9cd225b-4883-428e-82c2-73e0b6282fb6
# -------------------------------------------------------------
# Artist Lillasyster has the mbid 9acaf734-b380-4c48-954c-a2cf1d7990a9
# -------------------------------------------------------------
# Artist Lilu has the mbid d4d5ae85-700c-4a55-8a39-7f923da07ef2
# -------------------------------------------------------------
# Artist Lil' Scrappy has the mbid 77fafce8-a32f-4d42-bdce-266bbf913cee
# -------------------------------------------------------------
# Artist Lilys has the mbid 50ad1cde-1536-4268-a55f-e47a7b8280ab
# -------------------------------------------------------------
# Artist The Lillingtons has the mbid 9803d120-716d-45ba-9eb7-9a120813f908
# -------------------------------------------------------------
# Artist LIL PEEP has the mbid
# -------------------------------------------------------------
# Artist Leila has the mbid b27560ea-2783-4a91-be45-9e8711917562
# -------------------------------------------------------------
# Artist Lil Mama has the mbid 194e87c9-b3fe-4fbd-82a7-8c54b4dd4c76
# -------------------------------------------------------------
# Artist Lillix has the mbid fd90af91-ed07-4e85-8816-26c954fe5286
# -------------------------------------------------------------
# Artist Lily Chou-Chou has the mbid 5652bb3e-f225-49de-9637-5aa1539b4a7c
# -------------------------------------------------------------
# Artist Liliput has the mbid 83bae41e-e95e-4540-8dfa-2254563858dc
# -------------------------------------------------------------
# Artist Lil' Kleine has the mbid
# -------------------------------------------------------------
# Artist Amelia Lily has the mbid 48e114c4-91ba-4a6a-bea7-e7f6615f1dd4
# -------------------------------------------------------------
# Artist Mashrou' Leila has the mbid a31becdf-7b33-4409-9eb1-3f74bd72997c
# -------------------------------------------------------------
# Artist Lil Twist has the mbid c33d9d64-a760-43cd-bad3-520ed37bb004
# -------------------------------------------------------------
# Artist Lilly Wood & The Prick And Robin Schulz has the mbid 9f3d2229-6474-46d3-a1e0-f964dacb31d7
# -------------------------------------------------------------
# Artist Lillies and Remains has the mbid 0ccb214c-ab81-4216-9861-9e522c5ff063
# -------------------------------------------------------------
# Artist Lil Rob has the mbid ebeb8340-4c6c-417d-b759-339021b78345
# -------------------------------------------------------------
# Artist Lil Silva has the mbid f9e52b78-5499-4897-b979-7f430ec5b5cd
# -------------------------------------------------------------
# Artist Lil Scrappy has the mbid
# -------------------------------------------------------------
# Artist Lilium has the mbid 6af9f966-73fc-4a63-bcf1-e2065d994888
# -------------------------------------------------------------
# Artist Lilacs & Champagne has the mbid ba449da7-a682-4b21-8baa-e0c2ff30e950
# -------------------------------------------------------------
# Artist Lil Debbie has the mbid 5a481d80-c16d-48a7-8ab7-1e199f40175b
# -------------------------------------------------------------
# Artist Lil Herb has the mbid db1543f1-7b3c-4110-8e60-5a4b3d80d97c
# -------------------------------------------------------------
# Artist Lil' Keke has the mbid 251541e9-4212-4350-99f0-d347a055cda6
# -------------------------------------------------------------
# Artist Lil Bibby has the mbid 3a0f3db6-4178-4bdb-990d-d1db5284c5bf
# -------------------------------------------------------------
# Artist DJ Snake & Lil Jon has the mbid 31445b1e-96f3-4c7f-84ec-dd02e647e690
# -------------------------------------------------------------
# Artist Lil Keke has the mbid 251541e9-4212-4350-99f0-d347a055cda6
# -------------------------------------------------------------
# Artist Lilly Hates Roses has the mbid 39fbfa96-5626-4d23-81f4-fe1676615680
# -------------------------------------------------------------
# Artist Lil' Mo has the mbid
# -------------------------------------------------------------

# %% [markdown]
# ## 5) Find the artist's name and bio using their `mbid`.
#
# If you look at the [last.fm documentation](http://www.last.fm/api/show/artist.getInfo), you can see how to use the artist's `mbid` to find more information about them. Print **every tag associated with your artist**.
#
# - *Tip: It's a new request to the API*
# - *Tip: Use the `mbid`, and make sure you delete the `&name=Cher` from the sample endpoint*
# - *Tip: If you use `print` for the bio it looks a little nicer than it would otherwise*

# %%
mbid = "http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist=liljon&mbid=a95384b1-6aec-468c-ae0d-8c6daf87c4c2&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json"

# %%
bio = requests.get(mbid)
print(bio.text)
print(bio.json())
mbid_data = bio.json()
#do we have to keep telling it it's json?
# Out:
# {"artist":{"name":"Lil Jon","mbid":"a95384b1-6aec-468c-ae0d-8c6daf87c4c2","url":"https://www.last.fm/music/Lil+Jon","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/8e5029ce3e2b4998810e1234365134e8.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/8e5029ce3e2b4998810e1234365134e8.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/8e5029ce3e2b4998810e1234365134e8.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/8e5029ce3e2b4998810e1234365134e8.png","size":"extralarge"},{"#text":"https://lastfm-img2.akamaized.net/i/u/8e5029ce3e2b4998810e1234365134e8.png","size":"mega"},{"#text":"https://lastfm-img2.akamaized.net/i/u/arQ/8e5029ce3e2b4998810e1234365134e8.png","size":""}],"streamable":"0","ontour":"0","stats":{"listeners":"581672","playcount":"3469472"},"similar":{"artist":[{"name":"Lil Jon & The East Side Boyz","url":"https://www.last.fm/music/Lil+Jon+&+The+East+Side+Boyz","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/1d3b5aa94b794f999c14d15b2bafb136.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/1d3b5aa94b794f999c14d15b2bafb136.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/1d3b5aa94b794f999c14d15b2bafb136.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/1d3b5aa94b794f999c14d15b2bafb136.png","size":"extralarge"},{"#text":"https://lastfm-img2.akamaized.net/i/u/1d3b5aa94b794f999c14d15b2bafb136.png","size":"mega"},{"#text":"https://lastfm-img2.akamaized.net/i/u/arQ/1d3b5aa94b794f999c14d15b2bafb136.png","size":""}]},{"name":"Ying Yang Twins","url":"https://www.last.fm/music/Ying+Yang+Twins","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/addd36efadcd4834b7c781969264fec1.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/addd36efadcd4834b7c781969264fec1.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/addd36efadcd4834b7c781969264fec1.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/addd36efadcd4834b7c781969264fec1.png","size":"extralarge"},{"#text":"https://lastfm-img2.akamaized.net/i/u/addd36efadcd4834b7c781969264fec1.png","size":"mega"},{"#text":"https://lastfm-img2.akamaized.net/i/u/arQ/addd36efadcd4834b7c781969264fec1.png","size":""}]},{"name":"Flo Rida","url":"https://www.last.fm/music/Flo+Rida","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/5b6694a1c6e9408f9211c751b1e1012f.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/5b6694a1c6e9408f9211c751b1e1012f.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/5b6694a1c6e9408f9211c751b1e1012f.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/5b6694a1c6e9408f9211c751b1e1012f.png","size":"extralarge"},{"#text":"https://lastfm-img2.akamaized.net/i/u/5b6694a1c6e9408f9211c751b1e1012f.png","size":"mega"},{"#text":"https://lastfm-img2.akamaized.net/i/u/arQ/5b6694a1c6e9408f9211c751b1e1012f.png","size":""}]},{"name":"Pitbull","url":"https://www.last.fm/music/Pitbull","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/15b4b8e056d03db52f3efd1765b2b41c.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/15b4b8e056d03db52f3efd1765b2b41c.png","size":"medium"},{"#text":"https://lastfm-img2.akamaized.net/i/u/174s/15b4b8e056d03db52f3efd1765b2b41c.png","size":"large"},{"#text":"https://lastfm-img2.akamaized.net/i/u/300x300/15b4b8e056d03db52f3efd1765b2b41c.png","size":"extralarge"},{"#text":"https://lastfm-img2.akamaized.net/i/u/15b4b8e056d03db52f3efd1765b2b41c.png","size":"mega"},{"#text":"https://lastfm-img2.akamaized.net/i/u/arQ/15b4b8e056d03db52f3efd1765b2b41c.png","size":""}]},{"name":"YoungBloodz","url":"https://www.last.fm/music/YoungBloodz","image":[{"#text":"https://lastfm-img2.akamaized.net/i/u/34s/49712ce43a5c475db2a160f16fd74e70.png","size":"small"},{"#text":"https://lastfm-img2.akamaized.net/i/u/64s/49712c ...
# {'artist': {'name': 'Lil Jon', 'mbid': 'a95384b1-6aec-468c-ae0d-8c6daf87c4c2', 'url': 'https://www.last.fm/music/Lil+Jon', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/8e5029ce3e2b4998810e1234365134e8.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/8e5029ce3e2b4998810e1234365134e8.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/8e5029ce3e2b4998810e1234365134e8.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/8e5029ce3e2b4998810e1234365134e8.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/8e5029ce3e2b4998810e1234365134e8.png', 'size': 'mega'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/arQ/8e5029ce3e2b4998810e1234365134e8.png', 'size': ''}], 'streamable': '0', 'ontour': '0', 'stats': {'listeners': '581672', 'playcount': '3469472'}, 'similar': {'artist': [{'name': 'Lil Jon & The East Side Boyz', 'url': 'https://www.last.fm/music/Lil+Jon+&+The+East+Side+Boyz', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/1d3b5aa94b794f999c14d15b2bafb136.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/1d3b5aa94b794f999c14d15b2bafb136.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/1d3b5aa94b794f999c14d15b2bafb136.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/1d3b5aa94b794f999c14d15b2bafb136.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/1d3b5aa94b794f999c14d15b2bafb136.png', 'size': 'mega'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/arQ/1d3b5aa94b794f999c14d15b2bafb136.png', 'size': ''}]}, {'name': 'Ying Yang Twins', 'url': 'https://www.last.fm/music/Ying+Yang+Twins', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/addd36efadcd4834b7c781969264fec1.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/addd36efadcd4834b7c781969264fec1.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/addd36efadcd4834b7c781969264fec1.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/addd36efadcd4834b7c781969264fec1.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/addd36efadcd4834b7c781969264fec1.png', 'size': 'mega'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/arQ/addd36efadcd4834b7c781969264fec1.png', 'size': ''}]}, {'name': 'Flo Rida', 'url': 'https://www.last.fm/music/Flo+Rida', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/5b6694a1c6e9408f9211c751b1e1012f.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/5b6694a1c6e9408f9211c751b1e1012f.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/5b6694a1c6e9408f9211c751b1e1012f.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/5b6694a1c6e9408f9211c751b1e1012f.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/5b6694a1c6e9408f9211c751b1e1012f.png', 'size': 'mega'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/arQ/5b6694a1c6e9408f9211c751b1e1012f.png', 'size': ''}]}, {'name': 'Pitbull', 'url': 'https://www.last.fm/music/Pitbull', 'image': [{'#text': 'https://lastfm-img2.akamaized.net/i/u/34s/15b4b8e056d03db52f3efd1765b2b41c.png', 'size': 'small'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/64s/15b4b8e056d03db52f3efd1765b2b41c.png', 'size': 'medium'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/174s/15b4b8e056d03db52f3efd1765b2b41c.png', 'size': 'large'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/300x300/15b4b8e056d03db52f3efd1765b2b41c.png', 'size': 'extralarge'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/15b4b8e056d03db52f3efd1765b2b41c.png', 'size': 'mega'}, {'#text': 'https://lastfm-img2.akamaized.net/i/u/arQ/15b4b8e056d03db52f3efd1765b2b41c.png', 'size': ''}]}, {'name': 'YoungBloodz', 'url': 'https://www.last.fm/music/YoungBloodz', 'image': [ ...

# %% [markdown]
# ## 6) Print every tag of that artist

# %%
url_tags = "http://ws.audioscrobbler.com/2.0/?method=artist.getTags&artist=liljon&mbid=a95384b1-6aec-468c-ae0d-8c6daf87c4c2&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json"

# %%
tags = requests.get(url_tags)
print(tags.text)
print(tags.json())
tags_data = tags.json()
#getting "User not found" error message. what's going on??
# Out:
# {"error":6,"message":"User not found","links":[]}
# {'error': 6, 'message': 'User not found', 'links': []}

# %% [markdown]
# # GETTING A LITTLE CRAZY
#
# So you know your original list of musicians? I want to get tag data for ALL OF THEM. How are we going to do that?
#
# ## 7) Find the mbids (again)
#
# If we have a musician with an mbid of `AAA-AAA-AAA`, we get their info from a url like `http://ws.audioscrobbler.com/blahblah/?api_key=12345&mbid=AAA-AAA-AAA`.
#
# |artist|url|
# |---|---|
# |`AAA-AAA-AAA`|`http://ws.audioscrobbler.com/blahblah/?api_key=12345&mbid=AAA-AAA-AAA`|
# |`BBB-BBB-BBB`|`http://ws.audioscrobbler.com/blahblah/?api_key=12345&mbid=BBB-BBB-BBB`|
# |`CCC-CCC-CCC`|`http://ws.audioscrobbler.com/blahblah/?api_key=12345&mbid=CCC-CCC-CCC`|
#
# I guess we should start trying to get a list of all of the mbids.
#
# **Loop through your artists, and print out the `mbid` for each artist**
#
# - *Tip: You probably need to request your artist search result data again, because you probably saved over `data` with your other API request. Maybe call it `artist_data` this time?*
# - *Tip: If the artist does NOT have an `mbid`, don't print it.

# %%
#we can use the 'artist' variable we defined earlier for this:
#how to ignore nulls???!
for each_element in artist:
    print("The mbid for", each_element['name'], "is:", each_element['mbid'])
# Out:
# The mbid for Lil' Wayne is:
# The mbid for Lily Allen is: 6e0c7c0e-cba5-4c2c-a652-38f71ef5785d
# The mbid for Lil' Keke is: 251541e9-4212-4350-99f0-d347a055cda6
# The mbid for Lil Bibby is: 3a0f3db6-4178-4bdb-990d-d1db5284c5bf
# The mbid for DJ Snake & Lil Jon is: 31445b1e-96f3-4c7f-84ec-dd02e647e690
# The mbid for Lil Keke is: 251541e9-4212-4350-99f0-d347a055cda6
# The mbid for Lilly Hates Roses is: 39fbfa96-5626-4d23-81f4-fe1676615680
# The mbid for Lil' Mo is:

# %% [markdown]
# Your results should look something like
#
# ```
# 6e0c7c0e-cba5-4c2c-a652-38f71ef5785d
# 1550f952-c91b-40d7-9b4d-d26a259ee932
# 1b72331b-3a97-4981-a81c-eeee9c275d28
# 5f1adfe1-4d07-4141-b181-79e5d379d539
# a95384b1-6aec-468c-ae0d-8c6daf87c4c2
# bc1b5c95-e6d6-46b5-957a-5e8908b02c1e
# 243c6f61-d83b-4459-bebd-5899df0da111
# ```

# %% [markdown]
# ## 8) Saving those mbids
#
# For those `mbid` values, instead of printing them out, save them to a new list of just mbid values. Call this list `mbids`.
#
# - *Tip: Use `.append` to add a single element onto a list*

# %%
for each_element in artist:
    save_mbids = each_element['mbid']
    print(save_mbids)
# Out:
# 6e0c7c0e-cba5-4c2c-a652-38f71ef5785d
# 1550f952-c91b-40d7-9b4d-d26a259ee932
# 1b72331b-3a97-4981-a81c-eeee9c275d28
#
# 5f1adfe1-4d07-4141-b181-79e5d379d539
# a95384b1-6aec-468c-ae0d-8c6daf87c4c2
# bc1b5c95-e6d6-46b5-957a-5e8908b02c1e
# 243c6f61-d83b-4459-bebd-5899df0da111
#
# 8ba17cf6-bec2-4ae4-9820-b1cda47adc08
# ad29ae1c-2eda-4071-9dc8-31910e7e546c
# 3268f062-6e76-480a-a384-e1dd2a276afb
# 3ad4f6ec-253f-4050-8849-ca26266edfb8
# 9b5ce0c1-1bc0-4ea2-a8d3-f5ee7af9eda8
#
# 981d39fc-bd00-4cc6-ac67-6410f8b89098
# b89f4c50-72f5-48ce-b08c-a643b191b24f
# bc21df5c-3d79-479b-b638-8ddb5ecea403
# c9cd225b-4883-428e-82c2-73e0b6282fb6
# 9acaf734-b380-4c48-954c-a2cf1d7990a9
# d4d5ae85-700c-4a55-8a39-7f923da07ef2
# 77fafce8-a32f-4d42-bdce-266bbf913cee
# 50ad1cde-1536-4268-a55f-e47a7b8280ab
# 9803d120-716d-45ba-9eb7-9a120813f908
#
# b27560ea-2783-4a91-be45-9e8711917562
# 194e87c9-b3fe-4fbd-82a7-8c54b4dd4c76
# fd90af91-ed07-4e85-8816-26c954fe5286
# 5652bb3e-f225-49de-9637-5aa1539b4a7c
# 83bae41e-e95e-4540-8dfa-2254563858dc
#
# 48e114c4-91ba-4a6a-bea7-e7f6615f1dd4
# a31becdf-7b33-4409-9eb1-3f74bd72997c
# c33d9d64-a760-43cd-bad3-520ed37bb004
# 9f3d2229-6474-46d3-a1e0-f964dacb31d7
# 0ccb214c-ab81-4216-9861-9e522c5ff063
# ebeb8340-4c6c-417d-b759-339021b78345
# f9e52b78-5499-4897-b979-7f430ec5b5cd
#
# 6af9f966-73fc-4a63-bcf1-e2065d994888
# ba449da7-a682-4b21-8baa-e0c2ff30e950
# 5a481d80-c16d-48a7-8ab7-1e199f40175b
# db1543f1-7b3c-4110-8e60-5a4b3d80d97c
# 251541e9-4212-4350-99f0-d347a055cda6
# 3a0f3db6-4178-4bdb-990d-d1db5284c5bf
# 31445b1e-96f3-4c7f-84ec-dd02e647e690
# 251541e9-4212-4350-99f0-d347a055cda6
# 39fbfa96-5626-4d23-81f4-fe1676615680

# %% [markdown]
# Your results should look something like
#
# ```['6e0c7c0e-cba5-4c2c-a652-38f71ef5785d',
#  '1550f952-c91b-40d7-9b4d-d26a259ee932',
#  '1b72331b-3a97-4981-a81c-eeee9c275d28',
#  '5f1adfe1-4d07-4141-b181-79e5d379d539',
#  'a95384b1-6aec-468c-ae0d-8c6daf87c4c2',
#  'bc1b5c95-e6d6-46b5-957a-5e8908b02c1e',
#  '243c6f61-d83b-4459-bebd-5899df0da111',
#  '8ba17cf6-bec2-4ae4-9820-b1cda47adc08',
#  'ad29ae1c-2eda-4071-9dc8-31910e7e546c',
#  '3268f062-6e76-480a-a384-e1dd2a276afb',
#  '3ad4f6ec-253f-4050-8849-ca26266edfb8',
#  '9b5ce0c1-1bc0-4ea2-a8d3-f5ee7af9eda8',
#  '981d39fc-bd00-4cc6-ac67-6410f8b89098',
#  'b89f4c50-72f5-48ce-b08c-a643b191b24f',
#  'bc21df5c-3d79-479b-b638-8ddb5ecea403',
#  'c9cd225b-4883-428e-82c2-73e0b6282fb6',
#  '9acaf734-b380-4c48-954c-a2cf1d7990a9',
#  'd4d5ae85-700c-4a55-8a39-7f923da07ef2',
#  '77fafce8-a32f-4d42-bdce-266bbf913cee',
#  '50ad1cde-1536-4268-a55f-e47a7b8280ab',
#  '9803d120-716d-45ba-9eb7-9a120813f908',
#  'b27560ea-2783-4a91-be45-9e8711917562',
#  '194e87c9-b3fe-4fbd-82a7-8c54b4dd4c76',
#  'fd90af91-ed07-4e85-8816-26c954fe5286',
#  '5652bb3e-f225-49de-9637-5aa1539b4a7c']```

# %% [markdown]
# ## 9) Printing our API urls
#
# To get tag data for each artist, you need to use those `mbid` values to access their artist page on the API. Loop through the mbids, displying the URL you'll need to access.
#
# - *Tip: You don't want to use a comma when printing, because commas add spaces into your text and URLs can't have that*
# - *Tip: Make sure your URL has `artist.getinfo` in it - if not, you're using the wrong endpoint.*

# %%
for each_element in artist:
    mbid_url = ("http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json"+each_element['mbid'])
    print(mbid_url)
    print("----------------------------------------------------------")
# Out:
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json6e0c7c0e-cba5-4c2c-a652-38f71ef5785d
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json1550f952-c91b-40d7-9b4d-d26a259ee932
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json1b72331b-3a97-4981-a81c-eeee9c275d28
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json5f1adfe1-4d07-4141-b181-79e5d379d539
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=jsona95384b1-6aec-468c-ae0d-8c6daf87c4c2
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=jsonbc1b5c95-e6d6-46b5-957a-5e8908b02c1e
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json243c6f61-d83b-4459-bebd-5899df0da111
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json8ba17cf6-bec2-4ae4-9820-b1cda47adc08
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=jsonad29ae1c-2eda-4071-9dc8-31910e7e546c
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json3268f062-6e76-480a-a384-e1dd2a276afb
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json3ad4f6ec-253f-4050-8849-ca26266edfb8
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json9b5ce0c1-1bc0-4ea2-a8d3-f5ee7af9eda8
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json981d39fc-bd00-4cc6-ac67-6410f8b89098
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=jsonb89f4c50-72f5-48ce-b08c-a643b191b24f
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=jsonbc21df5c-3d79-479b-b638-8ddb5ecea403
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=jsonc9cd225b-4883-428e-82c2-73e0b6282fb6
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json9acaf734-b380-4c48-954c-a2cf1d7990a9
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=jsond4d5ae85-700c-4a55-8a39-7f923da07ef2
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json77fafce8-a32f-4d42-bdce-266bbf913cee
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json50ad1cde-1536-4268-a55f-e47a7b8280ab
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json9803d120-716d-45ba-9eb7-9a120813f908
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=jsonb27560ea-2783-4a91-be45-9e8711917562
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json194e87c9-b3fe-4fbd-82a7-8c54b4dd4c76
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=jsonfd90af91-ed07-4e85-8816-26c954fe5286
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json5652bb3e-f225-49de-9637-5aa1539b4a7c
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json83bae41e-e95e-4540-8dfa-2254563858dc
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json48e114c4-91ba-4a6a-bea7-e7f6615f1dd4
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=jsona31becdf-7b33-4409-9eb1-3f74bd72997c
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=jsonc33d9d64-a760-43cd-bad3-520ed37bb004
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json9f3d2229-6474-46d3-a1e0-f964dacb31d7
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json0ccb214c-ab81-4216-9861-9e522c5ff063
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=jsonebeb8340-4c6c-417d-b759-339021b78345
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=jsonf9e52b78-5499-4897-b979-7f430ec5b5cd
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json6af9f966-73fc-4a63-bcf1-e2065d994888
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=jsonba449da7-a682-4b21-8baa-e0c2ff30e950
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json5a481d80-c16d-48a7-8ab7-1e199f40175b
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=jsondb1543f1-7b3c-4110-8e60-5a4b3d80d97c
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json251541e9-4212-4350-99f0-d347a055cda6
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json3a0f3db6-4178-4bdb-990d-d1db5284c5bf
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json31445b1e-96f3-4c7f-84ec-dd02e647e690
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json251541e9-4212-4350-99f0-d347a055cda6
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json39fbfa96-5626-4d23-81f4-fe1676615680
# ----------------------------------------------------------
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=f700ab3104ce0a68942d14f72b4113bd&format=json
# ----------------------------------------------------------

# %% [markdown]
# Your results should look something like
#
# ```http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=6e0c7c0e-cba5-4c2c-a652-38f71ef5785d
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=1550f952-c91b-40d7-9b4d-d26a259ee932
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=1b72331b-3a97-4981-a81c-eeee9c275d28
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=5f1adfe1-4d07-4141-b181-79e5d379d539
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=a95384b1-6aec-468c-ae0d-8c6daf87c4c2
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=bc1b5c95-e6d6-46b5-957a-5e8908b02c1e```

# %% [markdown]
# ## OKAY HERE IS A LITTLE INFORMATION: Using our API urls
#
# This time instead of just *displaying* the URL, we're going to *request and process it*. **But first I'm going to teach you something.**
#
# When you're dealing with an API, you don't want to make a million requests, have bad code, and then need to do those million requests again. It's usually best to test your code with a few of the results first.
#
# So, if we have a list of numbers like this:

# %%
numbers = [4, 5, 6, 7]
numbers
# Out:
# [4, 5, 6, 7]

# %% [markdown]
# You can actually say to Python, **give me the first two**, and it will only give you the first two.

# %%
numbers[:2]
# Out:
# [4, 5]

# %% [markdown]
# The is **very convenient** with loopng with APIs, because instead of trying to use all FIFTY artists, you can just say "hey, please try this out with 2 of them" and you don't waste time.

# %% [markdown]
# ## 10) Using the first three `mbids`, request the API urls and print the artist's name.
#
# You built the URLs in the last question, now it's time to use them! Use `requests` etc to grab the URL and get out the artist's name.
#
# - *Tip: The code is the same as last time you got an artist's name from their info page, it's just going to be inside of a loop*
# - *Tip: USE `PRINT` TO SEE WHAT YOU ARE LOOKING AT!!!!!*

# %%
mbid_response = requests.get(mbid_url)
print(mbid_response.text)
#the artist you supplied could not be found...
# Out:
# {"error":6,"message":"The artist you supplied could not be found","links":[]}

# %% [markdown]
# ## 11) Using the first three `mbids`, request the API urls and print the artist's name and their tags
#
# - *Tip: The code is the same as last time you got an artist's name from their info page, it's just going to be inside of a loop*
# - *Tip: It's a for loop in a for loop!*

# %% [markdown]
# ## 12) Using the first ten mbids, print the artist's name and whether they're a rapper
#
# Only print their name ONCE and only print whether they are hip hop or not ONCE.
#
# - *Tip: Rap tags include hip hop, swag, crunk, rap, dirty south, and probably a bunch of other stuff! You can include as many categories as you'd like.*
# - *Tip: Every time you look at a new artist, you can say they are NOT a rapper. And once you find out one of their tags is hip hop or rap, then you can note that they're a rapper. Then once you're done looking at their tags, then you can say HEY this is a rapper, or HEY this is not a rapper.*

# %% [markdown]
# Your results might look something like
#
# ```ARTIST: Lily Allen
# NO hip hop
# ARTIST: Lil B
# YES hip hop
# ARTIST: Lilly Wood & The Prick
# NO hip hop
# ARTIST: Lil Ugly Mane
# YES hip hop
# ARTIST: Lil Jon
# YES hip hop
# ARTIST: Lil' Kim
# YES hip hop
# ARTIST: Lil Jon & The East Side Boyz
# YES hip hop
# ```

# %% [markdown]
# ## 13) What percent of "lil" results are rappers?

# %% [markdown]
# ## 14) Seriously you are all-powerful now.
