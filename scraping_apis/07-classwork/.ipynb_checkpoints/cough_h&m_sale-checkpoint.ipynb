# %% [markdown]
# # Scraping: H&M Sales
#
# **It's officially hot outside**, which means we need some summertime clothes. We live in New York City, though, so all our money goes to rent: we need to shop *as cheaply as possible*. So let's shop [sales at H&M](http://www.hm.com/us/products/sale)!
#
# **Answer the questions below using either Men's or Women's sale items at H&M.**
#
# ## Preparation: knowing your tags
#
# ### What is the tag name and class name for a product?
#
# Pages are not just in HTML anymore. They also use JS. When you visit it a page, it wants to get browser readable data to fill things in with. Computers use JSON to talk to each other.
# Network tab: we have things like IMG, CSS, **XHR (XML HTTP request) which basically means JSON or talking to an API.**
# Click on Preview and Response. It'll show you what came back from that request.
# Look at 'guide' in your network (search for it). Look at the url: http://api.hm.com/v2/us/en/search/guide. It's an API. If you look at the 'categories' (search for it) one, here's the url: http://api.hm.com/v2/us/en/products/categories?path=sale/ladies&deviceType=DESKTOP.
# They're both APIs. **FIND THEM IN THE XHR TAB UNDER NETWORK**

# %%
import requests
from bs4 import BeautifulSoup
response = requests.get('http://api.hm.com/v2/us/en/products/categories?path=sale/ladies&deviceType=DESKTOP')
#NOTE: if you try this with just http://hm.com it doesn't work. WHY???!

# %%
data = response.json()
data
# Out:
# {'categories': [{'categoryImages': [],
#    'count': 0,
#    'groupInfo': [{'displayState': 'EXPANDED',
#      'key': 'ladies/ladies-group',
#      'sortOrder': 1}],
#    'groupKey': 'online-areas',
#    'id': 'ladies',
#    'name': 'WOMEN',
#    'path': 'ladies',
#    'selected': False,
#    'trackingInfo': {},
#    'type': 'REGULAR'},
#   {'categoryImages': [],
#    'count': 0,
#    'groupInfo': [{'displayState': 'EXPANDED',
#      'key': 'men/men-group',
#      'sortOrder': 1}],
#    'groupKey': 'online-areas',
#    'id': 'men',
#    'name': 'MEN',
#    'path': 'men',
#    'selected': False,
#    'trackingInfo': {},
#    'type': 'REGULAR'},
#   {'categoryImages': [],
#    'count': 0,
#    'groupInfo': [{'displayState': 'EXPANDED',
#      'key': 'kids/kids-group',
#      'sortOrder': 1}],
#    'groupKey': 'online-areas',
#    'id': 'kids',
#    'name': 'KIDS',
#    'path': 'kids',
#    'selected': False,
#    'trackingInfo': {},
#    'type': 'REGULAR'},
#   {'categoryImages': [],
#    'count': 0,
#    'groupInfo': [{'displayState': 'EXPANDED',
#      'key': 'home/home-group',
#      'sortOrder': 1}],
#    'groupKey': 'online-areas',
#    'id': 'home',
#    'name': 'HOME',
#    'path': 'home',
#    'selected': False,
#    'trackingInfo': {},
#    'type': 'REGULAR'},
#   {'categoryImages': [],
#    'children': [{'categoryImages': [],
#      'children': [{'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'count': 17,
#          'groupKey': 'sale/ladies/selected/selected-groups',
#          'id': 'sale_ladies_selected_as-seen-on-instagram',
#          'name': 'As Seen On Instagram',
#          'path': 'sale/ladies/selected/as-seen-on-instagram',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SELECTED_AS_SEEN_ON_INSTAGRAM',
#           'metricPageID': 'SALE : Ladies : Selected : As Seen On Instagram',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3NlbGVjdGVkL2FzLXNlZW4tb24taW5zdGFncmFtOyM7IzsjOw'},
#          'type': 'SELECTED'},
#         {'categoryImages': [],
#          'count': 3,
#          'groupKey': 'sale/ladies/selected/selected-groups',
#          'id': 'sale_ladies_selected_stars-and-stripes',
#          'name': 'Stars & Stripes',
#          'path': 'sale/ladies/selected/stars-and-stripes',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SELECTED_STARS_STRIPES',
#           'metricPageID': 'SALE : LADIES : Selected : Stars & Stripes',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3NlbGVjdGVkL3N0YXJzLWFuZC1zdHJpcGVzOyM7IzsjOw'},
#          'type': 'SELECTED'},
#         {'categoryImages': [],
#          'count': 22,
#          'groupKey': 'sale/ladies/selected/selected-groups',
#          'id': 'sale_ladies_selected_womens-shoes-acc',
#          'name': 'Summer Shoes & Accessories',
#          'path': 'sale/ladies/selected/womens-shoes-acc',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SELECTED_SUMMER_SHOES_ACCESSORIES',
#           'metricPageID': 'SALE : LADIES : Selected : Summer Shoes & Accessories',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3NlbGVjdGVkL3dvbWVucy1zaG9lcy1hY2M7IzsjOyM7'},
#          'type': 'SELECTED'}],
#        'count': 2496,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/ladies/selected/selected-groups',
#          'sortOrder': 1}],
#        'groupKey': 'sale/ladies/ladies-group',
#        'id': 'sale_ladies_selected',
#        'name': 'Selected',
#        'path': 'sale/ladies/selected',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SELECTED',
#         'metricPageID': 'SALE : LADIES : Selected',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3NlbGVjdGVkOyM7IzsjOw'},
#        'type': 'SELECTED'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'count': 17,
#          'groupKey': 'sale/ladies/collaboration/collaboration-group',
#          'id': 'sale_ladies_collaboration_coachella',
#          'name': 'Coachella',
#          'path': 'sale/ladies/collaboration/coachella',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_COLLABORATION_COACHELLA',
#           'metricPageID': 'SALE : Ladies : Exclusive Collections : Coachella',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2NvbGxhYm9yYXRpb24vY29hY2hlbGxhOyM7IzsjOw'},
#          'type': 'COLLABORATION'}],
#        'count': 17,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/ladies/collaboration/collaboration-group',
#          'label': '',
#          'sortOrder': 1}],
#        'groupKey': 'sale/ladies/ladies-group',
#        'id': 'sale_ladies_collaboration',
#        'name': 'Exclusive Collections',
#        'path': 'sale/ladies/collaboration',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : LADIES_EXCLUSIVE_COLLECTIONS',
#         'metricPageID': 'SALE : LADIES : Exclusive Collections',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2NvbGxhYm9yYXRpb247IzsjOyM7'},
#        'type': 'COLLABORATION'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'count': 8,
#          'groupKey': 'sale/ladies/tops/tops-group',
#          'id': 'sale_ladies_tops_body',
#          'name': 'Body',
#          'path': 'sale/ladies/tops/body',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_TOPS_BODY',
#           'metricPageID': 'SALE : LADIES : Tops : Body',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3RvcHMvYm9keTsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 116,
#          'groupKey': 'sale/ladies/tops/tops-group',
#          'id': 'sale_ladies_tops_vests_sleeveless',
#          'name': 'Sleeveless',
#          'path': 'sale/ladies/tops/vests_sleeveless',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_TOPS_VESTS',
#           'metricPageID': 'SALE : LADIES : Tops : Vests',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3RvcHMvdmVzdHNfc2xlZXZlbGVzczsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 121,
#          'groupKey': 'sale/ladies/tops/tops-group',
#          'id': 'sale_ladies_tops_short_sleeved',
#          'name': 'Short Sleeve',
#          'path': 'sale/ladies/tops/short_sleeved',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_TOPS_SHORT_SLEEVES',
#           'metricPageID': 'SALE : Ladies : Tops : Short Sleeves',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3RvcHMvc2hvcnRfc2xlZXZlZDsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 116,
#          'groupKey': 'sale/ladies/tops/tops-group',
#          'id': 'sale_ladies_tops_long_sleeved',
#          'name': 'Long Sleeve',
#          'path': 'sale/ladies/tops/long_sleeved',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_TOPS_LONG_SLEEVES',
#           'metricPageID': 'SALE : Ladies : Tops : Long Sleeves',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3RvcHMvbG9uZ19zbGVldmVkOyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 31,
#          'groupKey': 'sale/ladies/tops/tops-group',
#          'id': 'sale_ladies_tops_croptops',
#          'name': 'Crop Tops',
#          'path': 'sale/ladies/tops/croptops',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_TOPS_CROPPED_TOPS',
#           'metricPageID': 'SALE : Ladies : Tops : Cropped Tops',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3RvcHMvY3JvcHRvcHM7IzsjOyM7'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 77,
#          'groupKey': 'sale/ladies/tops/tops-group',
#          'id': 'sale_ladies_tops_basics',
#          'name': 'Basics',
#          'path': 'sale/ladies/tops/basics',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_TOPS_BASICS',
#           'metricPageID': 'SALE : Ladies : Tops : Basics',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3RvcHMvYmFzaWNzOyM7IzsjOw'},
#          'type': 'REGULAR'}],
#        'count': 362,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/ladies/tops/tops-group',
#          'sortOrder': 1}],
#        'groupKey': 'sale/ladies/ladies-group',
#        'id': 'sale_ladies_tops',
#        'name': 'Tops',
#        'path': 'sale/ladies/tops',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : LADIES_TOPS',
#         'metricPageID': 'SALE : Ladies : Tops',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3RvcHM7IzsjOyM7'},
#        'type': 'REGULAR'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'count': 59,
#          'groupKey': 'sale/ladies/shirts_blouses/shirts-blouses-group',
#          'id': 'sale_ladies_shirts_blouses_shirts',
#          'name': 'Shirts',
#          'path': 'sale/ladies/shirts_blouses/shirts',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SHIRTS_BLOUSES_SHIRTS',
#           'metricPageID': 'SALE : Ladies : Shirts & Blouses : Shirts',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3NoaXJ0c19ibG91c2VzL3NoaXJ0czsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 93,
#          'groupKey': 'sale/ladies/shirts_blouses/shirts-blouses-group',
#          'id': 'sale_ladies_shirts_blouses_blouses',
#          'name': 'Blouses',
#          'path': 'sale/ladies/shirts_blouses/blouses',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SHIRTS_BLOUSES_BLOUSES',
#           'metricPageID': 'SALE : Ladies : Shirts & Blouses : Blouses',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3NoaXJ0c19ibG91c2VzL2Jsb3VzZXM7IzsjOyM7'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 7,
#          'groupKey': 'sale/ladies/shirts_blouses/shirts-blouses-group',
#          'id': 'sale_ladies_shirts_blouses_tunics',
#          'name': 'Tunics',
#          'path': 'sale/ladies/shirts_blouses/tunics',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SHIRTS_BLOUSES_TUNICS',
#           'metricPageID': 'SALE : Ladies : Shirts & Blouses : Tunics',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3NoaXJ0c19ibG91c2VzL3R1bmljczsjOyM7Izs'},
#          'type': 'REGULAR'}],
#        'count': 159,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/ladies/shirts_blouses/shirts-blouses-group',
#          'sortOrder': 1}],
#        'groupKey': 'sale/ladies/ladies-group',
#        'id': 'sale_ladies_shirts_blouses',
#        'name': 'Shirts & Blouses',
#        'path': 'sale/ladies/shirts_blouses',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SHIRTS_BLOUSES',
#         'metricPageID': 'SALE : Ladies : Shirts & Blouses',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3NoaXJ0c19ibG91c2VzOyM7IzsjOw'},
#        'type': 'REGULAR'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'count': 209,
#          'groupKey': 'sale/ladies/dresses/dresses-group',
#          'id': 'sale_ladies_dresses_shortdresses',
#          'name': 'Short Dresses',
#          'path': 'sale/ladies/dresses/shortdresses',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_DRESSES_SHORT_DRESSES',
#           'metricPageID': 'SALE : Ladies : Dresses : Short Dresses',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2RyZXNzZXMvc2hvcnRkcmVzc2VzOyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 39,
#          'groupKey': 'sale/ladies/dresses/dresses-group',
#          'id': 'sale_ladies_dresses_mididresses',
#          'name': 'Mid-length Dresses',
#          'path': 'sale/ladies/dresses/mididresses',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_DRESSES_MIDI_DRESSES',
#           'metricPageID': 'SALE : Ladies : Dresses : Midi Dresses',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2RyZXNzZXMvbWlkaWRyZXNzZXM7IzsjOyM7'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 6,
#          'groupKey': 'sale/ladies/dresses/dresses-group',
#          'id': 'sale_ladies_dresses_bodycon',
#          'name': 'Bodycon ',
#          'path': 'sale/ladies/dresses/bodycon',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_DRESSES_BODYCON',
#           'metricPageID': 'SALE : LADIES : Dresses : Bodycon',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2RyZXNzZXMvYm9keWNvbjsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 55,
#          'groupKey': 'sale/ladies/dresses/dresses-group',
#          'id': 'sale_ladies_dresses_partydresses',
#          'name': 'Party Dresses',
#          'path': 'sale/ladies/dresses/partydresses',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_DRESSES_PARTY_DRESSES',
#           'metricPageID': 'SALE : Ladies : Dresses : Party Dresses',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2RyZXNzZXMvcGFydHlkcmVzc2VzOyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 21,
#          'groupKey': 'sale/ladies/dresses/dresses-group',
#          'id': 'sale_ladies_dresses_maxidresses',
#          'name': 'Maxi  Dresses',
#          'path': 'sale/ladies/dresses/maxidresses',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_DRESSES_MAXI_DRESSES',
#           'metricPageID': 'SALE : Ladies : Dresses : Maxi  Dresses',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2RyZXNzZXMvbWF4aWRyZXNzZXM7IzsjOyM7'},
#          'type': 'REGULAR'}],
#        'count': 277,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/ladies/dresses/dresses-group',
#          'sortOrder': 1}],
#        'groupKey': 'sale/ladies/ladies-group',
#        'id': 'sale_ladies_dresses',
#        'name': 'Dresses',
#        'path': 'sale/ladies/dresses',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : LADIES_DRESSES',
#         'metricPageID': 'SALE : Ladies : Dresses',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2RyZXNzZXM7IzsjOyM7'},
#        'type': 'REGULAR'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'count': 9,
#          'groupKey': 'sale/ladies/jumpsuits/jumpsuits-group',
#          'id': 'sale_ladies_jumpsuits_short',
#          'name': 'Short',
#          'path': 'sale/ladies/jumpsuits/short',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_JUMPSUITS_SHORT',
#           'metricPageID': 'SALE : Ladies : Jumpsuits : Short',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2p1bXBzdWl0cy9zaG9ydDsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 9,
#          'groupKey': 'sale/ladies/jumpsuits/jumpsuits-group',
#          'id': 'sale_ladies_jumpsuits_long',
#          'name': 'Long',
#          'path': 'sale/ladies/jumpsuits/long',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_JUMPSUITS_LONG',
#           'metricPageID': 'SALE : Ladies : Jumpsuits : Long',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2p1bXBzdWl0cy9sb25nOyM7IzsjOw'},
#          'type': 'REGULAR'}],
#        'count': 20,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/ladies/jumpsuits/jumpsuits-group',
#          'sortOrder': 1}],
#        'groupKey': 'sale/ladies/ladies-group',
#        'id': 'sale_ladies_jumpsuits',
#        'name': 'Jumpsuits',
#        'path': 'sale/ladies/jumpsuits',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : LADIES_JUMPSUITS',
#         'metricPageID': 'SALE : Ladies : Jumpsuits',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2p1bXBzdWl0czsjOyM7Izs'},
#        'type': 'REGULAR'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'children': [{'categoryImages': [],
#            'count': 9,
#            'groupKey': 'sale/ladies/jeans/skinny/skinny-group',
#            'id': 'sale_ladies_jeans_skinny_skinnylow',
#            'name': 'Skinny low',
#            'path': 'sale/ladies/jeans/skinny/skinnylow',
#            'selected': False,
#            'trackingInfo': {'metricCategoryID': 'SALE : LADIES_JEANS_SKINNY_SKINNY_LOW',
#             'metricPageID': 'SALE : Ladies : Jeans : Skinny : Skinny low',
#             'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2plYW5zL3NraW5ueS9za2lubnlsb3c7IzsjOyM7'},
#            'type': 'REGULAR'},
#           {'categoryImages': [],
#            'count': 16,
#            'groupKey': 'sale/ladies/jeans/skinny/skinny-group',
#            'id': 'sale_ladies_jeans_skinny_skinnyregular',
#            'name': 'Skinny regular',
#            'path': 'sale/ladies/jeans/skinny/skinnyregular',
#            'selected': False,
#            'trackingInfo': {'metricCategoryID': 'SALE : LADIES_JEANS_SKINNY_SKINNY_REGULAR',
#             'metricPageID': 'SALE : Ladies : Jeans : Skinny : Skinny regular',
#             'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2plYW5zL3NraW5ueS9za2lubnlyZWd1bGFyOyM7IzsjOw'},
#            'type': 'REGULAR'},
#           {'categoryImages': [],
#            'count': 3,
#            'groupKey': 'sale/ladies/jeans/skinny/skinny-group',
#            'id': 'sale_ladies_jeans_skinny_skinnyhigh',
#            'name': 'Skinny High ',
#            'path': 'sale/ladies/jeans/skinny/skinnyhigh',
#            'selected': False,
#            'trackingInfo': {'metricCategoryID': 'SALE : LADIES_JEANS_SKINNY_SKINNY_HIGH',
#             'metricPageID': 'SALE : Ladies : Jeans : Skinny : Skinny high',
#             'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2plYW5zL3NraW5ueS9za2lubnloaWdoOyM7IzsjOw'},
#            'type': 'REGULAR'}],
#          'count': 22,
#          'groupInfo': [{'displayState': 'EXPANDED',
#            'key': 'sale/ladies/jeans/skinny/skinny-group',
#            'sortOrder': 1}],
#          'groupKey': 'sale/ladies/jeans/jeans-group',
#          'id': 'sale_ladies_jeans_skinny',
#          'name': 'Skinny',
#          'path': 'sale/ladies/jeans/skinny',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_JEANS_SKINNY',
#           'metricPageID': 'SALE : Ladies : Jeans : Skinny',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2plYW5zL3NraW5ueTsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 4,
#          'groupKey': 'sale/ladies/jeans/jeans-group',
#          'id': 'sale_ladies_jeans_shaping',
#          'name': 'Shaping ',
#          'path': 'sale/ladies/jeans/shaping',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_JEANS_SHAPING',
#           'metricPageID': 'SALE : Ladies : Jeans : Shaping',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2plYW5zL3NoYXBpbmc7IzsjOyM7'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 13,
#          'groupKey': 'sale/ladies/jeans/jeans-group',
#          'id': 'sale_ladies_jeans_straight',
#          'name': 'Straight ',
#          'path': 'sale/ladies/jeans/straight',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_JEANS_STRAIGHT',
#           'metricPageID': 'SALE : LADIES : Jeans : Straight',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2plYW5zL3N0cmFpZ2h0OyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 2,
#          'groupKey': 'sale/ladies/jeans/jeans-group',
#          'id': 'sale_ladies_jeans_flare',
#          'name': 'Flare',
#          'path': 'sale/ladies/jeans/flare',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_JEANS_FLARE',
#           'metricPageID': 'SALE : Ladies : Jeans : Flare',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2plYW5zL2ZsYXJlOyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 5,
#          'groupKey': 'sale/ladies/jeans/jeans-group',
#          'id': 'sale_ladies_jeans_loose',
#          'name': 'Loose',
#          'path': 'sale/ladies/jeans/loose',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_JEANS_LOOSE',
#           'metricPageID': 'SALE : Ladies : Jeans : Loose',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2plYW5zL2xvb3NlOyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 14,
#          'groupKey': 'sale/ladies/jeans/jeans-group',
#          'id': 'sale_ladies_jeans_slim',
#          'name': 'Slim',
#          'path': 'sale/ladies/jeans/slim',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_JEANS_SLIM',
#           'metricPageID': 'SALE : Ladies : Jeans : Slim',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2plYW5zL3NsaW07IzsjOyM7'},
#          'type': 'REGULAR'}],
#        'count': 58,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/ladies/jeans/jeans-group',
#          'sortOrder': 1}],
#        'groupKey': 'sale/ladies/ladies-group',
#        'id': 'sale_ladies_jeans',
#        'name': 'Jeans',
#        'path': 'sale/ladies/jeans',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : LADIES_JEANS',
#         'metricPageID': 'SALE : Ladies : Jeans',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2plYW5zOyM7IzsjOw'},
#        'type': 'REGULAR'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'count': 41,
#          'groupKey': 'sale/ladies/trousers/trousers-group',
#          'id': 'sale_ladies_trousers_slim',
#          'name': 'Slim',
#          'path': 'sale/ladies/trousers/slim',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_TROUSERS_SLIM',
#           'metricPageID': 'SALE : LADIES : Trousers : Slim',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Ryb3VzZXJzL3NsaW07IzsjOyM7'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 16,
#          'groupKey': 'sale/ladies/trousers/trousers-group',
#          'id': 'sale_ladies_trousers_leggings',
#          'name': 'Leggings',
#          'path': 'sale/ladies/trousers/leggings',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_TROUSERS_LEGGINGS',
#           'metricPageID': 'SALE : Ladies : Trousers : Leggings',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Ryb3VzZXJzL2xlZ2dpbmdzOyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 12,
#          'groupKey': 'sale/ladies/trousers/trousers-group',
#          'id': 'sale_ladies_trousers_joggers',
#          'name': 'Joggers',
#          'path': 'sale/ladies/trousers/joggers',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_TROUSERS_JOGGERS',
#           'metricPageID': 'SALE : Ladies : Trousers : Joggers',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Ryb3VzZXJzL2pvZ2dlcnM7IzsjOyM7'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 3,
#          'groupKey': 'sale/ladies/trousers/trousers-group',
#          'id': 'sale_ladies_trousers_chinos',
#          'name': 'Chinos',
#          'path': 'sale/ladies/trousers/chinos',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_TROUSERS_CHINOS',
#           'metricPageID': 'SALE : Ladies : Trousers : Chinos',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Ryb3VzZXJzL2NoaW5vczsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 1,
#          'groupKey': 'sale/ladies/trousers/trousers-group',
#          'id': 'sale_ladies_trousers_slacks',
#          'name': 'Slacks',
#          'path': 'sale/ladies/trousers/slacks',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_TROUSERS_SLACKS',
#           'metricPageID': 'SALE : Ladies : Trousers : Slacks',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Ryb3VzZXJzL3NsYWNrczsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 29,
#          'groupKey': 'sale/ladies/trousers/trousers-group',
#          'id': 'sale_ladies_trousers_loose',
#          'name': 'Loose',
#          'path': 'sale/ladies/trousers/loose',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_TROUSERS_LOOSE',
#           'metricPageID': 'SALE : Ladies : Trousers : Loose',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Ryb3VzZXJzL2xvb3NlOyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 19,
#          'groupKey': 'sale/ladies/trousers/trousers-group',
#          'id': 'sale_ladies_trousers_dressed',
#          'name': 'Dressed',
#          'path': 'sale/ladies/trousers/dressed',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_TROUSERS_DRESSED',
#           'metricPageID': 'SALE : Ladies : Trousers : Dressed',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Ryb3VzZXJzL2RyZXNzZWQ7IzsjOyM7'},
#          'type': 'REGULAR'}],
#        'count': 128,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/ladies/trousers/trousers-group',
#          'sortOrder': 1}],
#        'groupKey': 'sale/ladies/ladies-group',
#        'id': 'sale_ladies_trousers',
#        'name': 'Pants',
#        'path': 'sale/ladies/trousers',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : LADIES_TROUSERS',
#         'metricPageID': 'SALE : Ladies : Trousers',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Ryb3VzZXJzOyM7IzsjOw'},
#        'type': 'REGULAR'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'count': 22,
#          'groupKey': 'sale/ladies/cardigans_jumpers/cardigans-jumpers-group',
#          'id': 'sale_ladies_cardigans_jumpers_cardigans',
#          'name': 'Cardigans',
#          'path': 'sale/ladies/cardigans_jumpers/cardigans',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_CARDIGANS_JUMPERS_CARDIGANS',
#           'metricPageID': 'SALE : Ladies : Cardigans & Jumpers : Cardigans',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2NhcmRpZ2Fuc19qdW1wZXJzL2NhcmRpZ2FuczsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 190,
#          'groupKey': 'sale/ladies/cardigans_jumpers/cardigans-jumpers-group',
#          'id': 'sale_ladies_cardigans_jumpers_jumpers',
#          'name': 'Pullovers',
#          'path': 'sale/ladies/cardigans_jumpers/jumpers',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_CARDIGANS_JUMPERS_JUMPERS',
#           'metricPageID': 'SALE : Ladies : Cardigans & Jumpers : Jumpers',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2NhcmRpZ2Fuc19qdW1wZXJzL2p1bXBlcnM7IzsjOyM7'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 25,
#          'groupKey': 'sale/ladies/cardigans_jumpers/cardigans-jumpers-group',
#          'id': 'sale_ladies_cardigans_jumpers_turtlenecks',
#          'name': 'Turtlenecks',
#          'path': 'sale/ladies/cardigans_jumpers/turtlenecks',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_CARDIGANS_JUMPERS_TURTLENECKS',
#           'metricPageID': 'SALE : Ladies : Cardigans & Jumpers : Turtlenecks',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2NhcmRpZ2Fuc19qdW1wZXJzL3R1cnRsZW5lY2tzOyM7IzsjOw'},
#          'type': 'REGULAR'}],
#        'count': 218,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/ladies/cardigans_jumpers/cardigans-jumpers-group',
#          'sortOrder': 1}],
#        'groupKey': 'sale/ladies/ladies-group',
#        'id': 'sale_ladies_cardigans_jumpers',
#        'name': 'Cardigans & Sweaters',
#        'path': 'sale/ladies/cardigans_jumpers',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : LADIES_CARDIGANS_JUMPERS',
#         'metricPageID': 'SALE : Ladies : Cardigans & Jumpers',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2NhcmRpZ2Fuc19qdW1wZXJzOyM7IzsjOw'},
#        'type': 'REGULAR'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'count': 16,
#          'groupKey': 'sale/ladies/hoodies_sweatshirts/hoodies-sweatshirts-group',
#          'id': 'sale_ladies_hoodies_sweatshirts_hoodies',
#          'name': 'Hoodies ',
#          'path': 'sale/ladies/hoodies_sweatshirts/hoodies',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_HOODIES_SWEATSHIRTS_HOODIES',
#           'metricPageID': 'SALE : LADIES : Hoodies & Sweatshirts : Hoodies',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2hvb2RpZXNfc3dlYXRzaGlydHMvaG9vZGllczsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 40,
#          'groupKey': 'sale/ladies/hoodies_sweatshirts/hoodies-sweatshirts-group',
#          'id': 'sale_ladies_hoodies_sweatshirts_sweatshirts',
#          'name': 'Sweatshirts',
#          'path': 'sale/ladies/hoodies_sweatshirts/sweatshirts',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_HOODIES_SWEATSHIRTS_SWEATSHIRTS',
#           'metricPageID': 'SALE : Ladies : Hoodies & Sweatshirts : Sweatshirts',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2hvb2RpZXNfc3dlYXRzaGlydHMvc3dlYXRzaGlydHM7IzsjOyM7'},
#          'type': 'REGULAR'}],
#        'count': 71,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/ladies/hoodies_sweatshirts/hoodies-sweatshirts-group',
#          'sortOrder': 1}],
#        'groupKey': 'sale/ladies/ladies-group',
#        'id': 'sale_ladies_hoodies_sweatshirts',
#        'name': 'Hoodies & Sweatshirts',
#        'path': 'sale/ladies/hoodies_sweatshirts',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : LADIES_HOODIES_SWEATSHIRTS',
#         'metricPageID': 'SALE : Ladies : Hoodies & Sweatshirts',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL2hvb2RpZXNfc3dlYXRzaGlydHM7IzsjOyM7'},
#        'type': 'REGULAR'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'count': 3,
#          'groupKey': 'sale/ladies/shorts/shorts-group',
#          'id': 'sale_ladies_shorts_denimshorts',
#          'name': 'Denim Shorts',
#          'path': 'sale/ladies/shorts/denimshorts',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SHORTS_DENIM_SHORTS',
#           'metricPageID': 'SALE : Ladies : Shorts : Denim shorts',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Nob3J0cy9kZW5pbXNob3J0czsjOyM7Izs'},
#          'type': 'REGULAR'}],
#        'count': 16,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/ladies/shorts/shorts-group',
#          'sortOrder': 1}],
#        'groupKey': 'sale/ladies/ladies-group',
#        'id': 'sale_ladies_shorts',
#        'name': 'Shorts',
#        'path': 'sale/ladies/shorts',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SHORTS',
#         'metricPageID': 'SALE : Ladies : Shorts',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Nob3J0czsjOyM7Izs'},
#        'type': 'REGULAR'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'count': 51,
#          'groupKey': 'sale/ladies/skirts/skirts-group',
#          'id': 'sale_ladies_skirts_shorts',
#          'name': 'Short Skirts',
#          'path': 'sale/ladies/skirts/shorts',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SKIRTS_SHORT_SKIRTS',
#           'metricPageID': 'SALE : Ladies : Skirts : Short Skirts',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3NraXJ0cy9zaG9ydHM7IzsjOyM7'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 31,
#          'groupKey': 'sale/ladies/skirts/skirts-group',
#          'id': 'sale_ladies_skirts_midi',
#          'name': 'Midi Skirts',
#          'path': 'sale/ladies/skirts/midi',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SKIRTS_MIDI_SKIRTS',
#           'metricPageID': 'SALE : Ladies : Skirts : Midi Skirts',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3NraXJ0cy9taWRpOyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 6,
#          'groupKey': 'sale/ladies/skirts/skirts-group',
#          'id': 'sale_ladies_skirts_long',
#          'name': 'Long Skirts',
#          'path': 'sale/ladies/skirts/long',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SKIRTS_MAXI_SKIRTS',
#           'metricPageID': 'SALE : Ladies : Skirts : Maxi Skirts',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3NraXJ0cy9sb25nOyM7IzsjOw'},
#          'type': 'REGULAR'}],
#        'count': 98,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/ladies/skirts/skirts-group',
#          'sortOrder': 1}],
#        'groupKey': 'sale/ladies/ladies-group',
#        'id': 'sale_ladies_skirts',
#        'name': 'Skirts',
#        'path': 'sale/ladies/skirts',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SKIRTS',
#         'metricPageID': 'SALE : Ladies : Skirts',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3NraXJ0czsjOyM7Izs'},
#        'type': 'REGULAR'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'count': 23,
#          'groupKey': 'sale/ladies/shoes/shoes-group',
#          'id': 'sale_ladies_shoes_pumps_heels',
#          'name': 'Pumps & High Heels',
#          'path': 'sale/ladies/shoes/pumps_heels',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SHOES_PUMPS_HIGH_HEELS',
#           'metricPageID': 'SALE : Ladies : Shoes : Pumps & High heels',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Nob2VzL3B1bXBzX2hlZWxzOyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 16,
#          'groupKey': 'sale/ladies/shoes/shoes-group',
#          'id': 'sale_ladies_shoes_ballerinas_flats',
#          'name': 'Ballerinas & Flats',
#          'path': 'sale/ladies/shoes/ballerinas_flats',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SHOES_BALLERINAS_FLATS',
#           'metricPageID': 'SALE : Ladies : Shoes : Ballerinas & Flats',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Nob2VzL2JhbGxlcmluYXNfZmxhdHM7IzsjOyM7'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 5,
#          'groupKey': 'sale/ladies/shoes/shoes-group',
#          'id': 'sale_ladies_shoes_sandals_espadrilles',
#          'name': 'Sandals & Espadrilles',
#          'path': 'sale/ladies/shoes/sandals_espadrilles',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SHOES_SANDALS_ESPADRILLES',
#           'metricPageID': 'SALE : Ladies : Shoes : Sandals & Espadrilles',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Nob2VzL3NhbmRhbHNfZXNwYWRyaWxsZXM7IzsjOyM7'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 9,
#          'groupKey': 'sale/ladies/shoes/shoes-group',
#          'id': 'sale_ladies_shoes_sneakers',
#          'name': 'Sneakers',
#          'path': 'sale/ladies/shoes/sneakers',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SHOES_SNEAKERS',
#           'metricPageID': 'SALE : Ladies : Shoes : Sneakers',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Nob2VzL3NuZWFrZXJzOyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 43,
#          'groupKey': 'sale/ladies/shoes/shoes-group',
#          'id': 'sale_ladies_shoes_boots',
#          'name': 'Boots',
#          'path': 'sale/ladies/shoes/boots',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SHOES_BOOTS',
#           'metricPageID': 'SALE : Ladies : Shoes : Boots',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Nob2VzL2Jvb3RzOyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 30,
#          'groupKey': 'sale/ladies/shoes/shoes-group',
#          'id': 'sale_ladies_shoes_pq',
#          'name': 'Premium Quality',
#          'path': 'sale/ladies/shoes/pq',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SHOES_PREMIUM_QUALITY',
#           'metricPageID': 'SALE : Ladies : Shoes : Premium Quality',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Nob2VzL3BxOyM7IzsjOw'},
#          'type': 'REGULAR'}],
#        'count': 106,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/ladies/shoes/shoes-group',
#          'sortOrder': 1}],
#        'groupKey': 'sale/ladies/ladies-group',
#        'id': 'sale_ladies_shoes',
#        'name': 'Shoes',
#        'path': 'sale/ladies/shoes',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SHOES',
#         'metricPageID': 'SALE : Ladies : Shoes',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3Nob2VzOyM7IzsjOw'},
#        'type': 'REGULAR'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'children': [{'categoryImages': [],
#            'count': 4,
#            'groupKey': 'sale/ladies/swimwear/bikini/bikini-group',
#            'id': 'sale_ladies_swimwear_bikini_bikini_tops',
#            'name': 'Bikini Tops',
#            'path': 'sale/ladies/swimwear/bikini/bikini_tops',
#            'selected': False,
#            'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SWIMWEAR_BIKINI_BIKINI_TOPS',
#             'metricPageID': 'SALE : Ladies : Swimwear : Bikini : Bikini Tops',
#             'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3N3aW13ZWFyL2Jpa2luaS9iaWtpbmlfdG9wczsjOyM7Izs'},
#            'type': 'REGULAR'},
#           {'categoryImages': [],
#            'count': 10,
#            'groupKey': 'sale/ladies/swimwear/bikini/bikini-group',
#            'id': 'sale_ladies_swimwear_bikini_bikini_bottoms',
#            'name': 'Bikini Bottoms',
#            'path': 'sale/ladies/swimwear/bikini/bikini_bottoms',
#            'selected': False,
#            'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SWIMWEAR_BIKINI_BIKINI_BOTTOMS',
#             'metricPageID': 'SALE : LADIES : Swimwear : Bikini : Bikini Bottoms',
#             'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3N3aW13ZWFyL2Jpa2luaS9iaWtpbmlfYm90dG9tczsjOyM7Izs'},
#            'type': 'REGULAR'}],
#          'count': 16,
#          'groupInfo': [{'displayState': 'EXPANDED',
#            'key': 'sale/ladies/swimwear/bikini/bikini-group',
#            'sortOrder': 1}],
#          'groupKey': 'sale/ladies/swimwear/swimwear-group',
#          'id': 'sale_ladies_swimwear_bikini',
#          'name': 'Bikini',
#          'path': 'sale/ladies/swimwear/bikini',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SWIMWEAR_BIKINI',
#           'metricPageID': 'SALE : Ladies : Swimwear : Bikini',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3N3aW13ZWFyL2Jpa2luaTsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 18,
#          'groupKey': 'sale/ladies/swimwear/swimwear-group',
#          'id': 'sale_ladies_swimwear_beachwear',
#          'name': 'Beachwear',
#          'path': 'sale/ladies/swimwear/beachwear',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SWIMWEAR_BEACH_WEAR',
#           'metricPageID': 'SALE : Ladies : Swimwear : Beach wear',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7bGFkaWVzL3N3aW13ZWFyL2JlYWNod2VhcjsjOyM7Izs'},
#          'type': 'REGULAR'}],
#        'count': 34,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/ladies/swimwear/swimwear-group',
#          'sortOrder': 1}],
#        'groupKey': 'sale/ladies/ladies-group',
#        'id': 'sale_ladies_swimwear',
#        'name': 'Swimwear',
#        'path': 'sale/ladies/swimwear',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : LADIES_SWIMWEAR',
#         'metricPageID': 'SALE : Ladies : Swimwear',
# ...
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS90b3dlbHM7IzsjOyM7'},
#        'type': 'REGULAR'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'count': 2,
#          'groupKey': 'sale/home/storage/storage-group',
#          'id': 'sale_home_storage_small-storage',
#          'name': 'Small Storage',
#          'path': 'sale/home/storage/small-storage',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_STORAGE_SMALL_STORAGE',
#           'metricPageID': 'SALE : Home : Storage : Small Storage',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9zdG9yYWdlL3NtYWxsLXN0b3JhZ2U7IzsjOyM7'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 11,
#          'groupKey': 'sale/home/storage/storage-group',
#          'id': 'sale_home_storage_boxes',
#          'name': 'Boxes',
#          'path': 'sale/home/storage/boxes',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_STORAGE_BOXES',
#           'metricPageID': 'SALE : Home : Storage : Boxes',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9zdG9yYWdlL2JveGVzOyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 6,
#          'groupKey': 'sale/home/storage/storage-group',
#          'id': 'sale_home_storage_kids-storage',
#          'name': 'Kids Storage',
#          'path': 'sale/home/storage/kids-storage',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_STORAGE_KIDS_STORAGE',
#           'metricPageID': 'SALE : Home : Storage : Kids Storage',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9zdG9yYWdlL2tpZHMtc3RvcmFnZTsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 10,
#          'groupKey': 'sale/home/storage/storage-group',
#          'id': 'sale_home_storage_basket',
#          'name': 'Baskets',
#          'path': 'sale/home/storage/basket',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_STORAGE_BASKETS',
#           'metricPageID': 'SALE : HOME : Storage : Baskets',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9zdG9yYWdlL2Jhc2tldDsjOyM7Izs'},
#          'type': 'REGULAR'}],
#        'count': 28,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/home/storage/storage-group',
#          'sortOrder': 2}],
#        'groupKey': 'sale/home/home-group',
#        'id': 'sale_home_storage',
#        'name': 'Storage',
#        'path': 'sale/home/storage',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : HOME_STORAGE',
#         'metricPageID': 'SALE : HOME : Storage',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9zdG9yYWdlOyM7IzsjOw'},
#        'type': 'REGULAR'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'count': 8,
#          'groupKey': 'sale/home/decorations/decorations-group',
#          'id': 'sale_home_decorations_candles',
#          'name': 'Candles',
#          'path': 'sale/home/decorations/candles',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_DECORATIONS_CANDLES',
#           'metricPageID': 'SALE : Home : Decorations : Candles',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9kZWNvcmF0aW9ucy9jYW5kbGVzOyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 12,
#          'groupKey': 'sale/home/decorations/decorations-group',
#          'id': 'sale_home_decorations_candle-holders',
#          'name': 'Candle Holders',
#          'path': 'sale/home/decorations/candle-holders',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_DECORATIONS_CANDLE_HOLDERS',
#           'metricPageID': 'SALE : Home : Decorations : Candle Holders',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9kZWNvcmF0aW9ucy9jYW5kbGUtaG9sZGVyczsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 4,
#          'groupKey': 'sale/home/decorations/decorations-group',
#          'id': 'sale_home_decorations_vases',
#          'name': 'Vases',
#          'path': 'sale/home/decorations/vases',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_DECORATIONS_VASES',
#           'metricPageID': 'SALE : Home : Decorations : Vases',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9kZWNvcmF0aW9ucy92YXNlczsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 1,
#          'groupKey': 'sale/home/decorations/decorations-group',
#          'id': 'sale_home_decorations_trays',
#          'name': 'Trays',
#          'path': 'sale/home/decorations/trays',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_DECORATIONS_TRAYS',
#           'metricPageID': 'SALE : Home : Decorations : Trays',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9kZWNvcmF0aW9ucy90cmF5czsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 3,
#          'groupKey': 'sale/home/decorations/decorations-group',
#          'id': 'sale_home_decorations_knobs',
#          'name': 'Knobs',
#          'path': 'sale/home/decorations/knobs',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_DECORATIONS_KNOBS',
#           'metricPageID': 'SALE : Home : Decorations : Knobs',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9kZWNvcmF0aW9ucy9rbm9iczsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 2,
#          'groupKey': 'sale/home/decorations/decorations-group',
#          'id': 'sale_home_decorations_hooks',
#          'name': 'Hooks',
#          'path': 'sale/home/decorations/hooks',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_DECORATIONS_HOOKS',
#           'metricPageID': 'SALE : Home : Decorations : Hooks',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9kZWNvcmF0aW9ucy9ob29rczsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 1,
#          'groupKey': 'sale/home/decorations/decorations-group',
#          'id': 'sale_home_decorations_mirror',
#          'name': 'Mirror',
#          'path': 'sale/home/decorations/mirror',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_DECORATIONS_MIRROR',
#           'metricPageID': 'SALE : Home : Decorations : Mirror',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9kZWNvcmF0aW9ucy9taXJyb3I7IzsjOyM7'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 1,
#          'groupKey': 'sale/home/decorations/decorations-group',
#          'id': 'sale_home_decorations_frames',
#          'name': 'Frames',
#          'path': 'sale/home/decorations/frames',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_DECORATIONS_FRAMES',
#           'metricPageID': 'SALE : Home : Decorations : Frames',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9kZWNvcmF0aW9ucy9mcmFtZXM7IzsjOyM7'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 3,
#          'groupKey': 'sale/home/decorations/decorations-group',
#          'id': 'sale_home_decorations_kitchen-utensils',
#          'name': 'Kitchen Utensils',
#          'path': 'sale/home/decorations/kitchen-utensils',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_DECORATIONS_KITCHEN_UTENSILS',
#           'metricPageID': 'SALE : Home : Decorations : Kitchen Utensils',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9kZWNvcmF0aW9ucy9raXRjaGVuLXV0ZW5zaWxzOyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 1,
#          'groupKey': 'sale/home/decorations/decorations-group',
#          'id': 'sale_home_decorations_bath-accessories',
#          'name': 'Bath Accessories',
#          'path': 'sale/home/decorations/bath-accessories',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_DECORATIONS_BATH_ACCESSORIES',
#           'metricPageID': 'SALE : Home : Decorations : Bath Accessories',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9kZWNvcmF0aW9ucy9iYXRoLWFjY2Vzc29yaWVzOyM7IzsjOw'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 6,
#          'groupKey': 'sale/home/decorations/decorations-group',
#          'id': 'sale_home_decorations_kids-decoration',
#          'name': 'Kids Decoration',
#          'path': 'sale/home/decorations/kids-decoration',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_DECORATIONS_KIDS_DECORATION',
#           'metricPageID': 'SALE : Home : Decorations : Kids Decoration',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9kZWNvcmF0aW9ucy9raWRzLWRlY29yYXRpb247IzsjOyM7'},
#          'type': 'REGULAR'}],
#        'count': 44,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/home/decorations/decorations-group',
#          'sortOrder': 1}],
#        'groupKey': 'sale/home/home-group',
#        'id': 'sale_home_decorations',
#        'name': 'Decorations',
#        'path': 'sale/home/decorations',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : HOME_DECORATIONS',
#         'metricPageID': 'SALE : Home : Decorations',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9kZWNvcmF0aW9uczsjOyM7Izs'},
#        'type': 'REGULAR'},
#       {'categoryImages': [],
#        'children': [{'categoryImages': [],
#          'count': 10,
#          'groupKey': 'sale/home/servingware/servingware-group',
#          'id': 'sale_home_servingware_mugs-glasses',
#          'name': 'Mugs & Glasses',
#          'path': 'sale/home/servingware/mugs-glasses',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_SERVINGWARE_MUGS_GLASSES',
#           'metricPageID': 'SALE : Home : Servingware : Mugs & Glasses',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9zZXJ2aW5nd2FyZS9tdWdzLWdsYXNzZXM7IzsjOyM7'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 13,
#          'groupKey': 'sale/home/servingware/servingware-group',
#          'id': 'sale_home_servingware_plates-bowls',
#          'name': 'Plates & Bowls',
#          'path': 'sale/home/servingware/plates-bowls',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_SERVINGWARE_PLATES_BOWLS',
#           'metricPageID': 'SALE : Home : Servingware : Plates & Bowls',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9zZXJ2aW5nd2FyZS9wbGF0ZXMtYm93bHM7IzsjOyM7'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 6,
#          'groupKey': 'sale/home/servingware/servingware-group',
#          'id': 'sale_home_servingware_jugs-carafs',
#          'name': 'Jugs & Carafs',
#          'path': 'sale/home/servingware/jugs-carafs',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_SERVINGWARE_JUGS_CARAFS',
#           'metricPageID': 'SALE : Home : Servingware : Jugs & Carafs',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9zZXJ2aW5nd2FyZS9qdWdzLWNhcmFmczsjOyM7Izs'},
#          'type': 'REGULAR'},
#         {'categoryImages': [],
#          'count': 3,
#          'groupKey': 'sale/home/servingware/servingware-group',
#          'id': 'sale_home_servingware_kids-kitchen',
#          'name': 'Kids Kitchen',
#          'path': 'sale/home/servingware/kids-kitchen',
#          'selected': False,
#          'trackingInfo': {'metricCategoryID': 'SALE : HOME_SERVINGWARE_KIDS_KITCHEN',
#           'metricPageID': 'SALE : Home : Servingware : Kids Kitchen',
#           'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9zZXJ2aW5nd2FyZS9raWRzLWtpdGNoZW47IzsjOyM7'},
#          'type': 'REGULAR'}],
#        'count': 30,
#        'groupInfo': [{'displayState': 'EXPANDED',
#          'key': 'sale/home/servingware/servingware-group',
#          'sortOrder': 1}],
#        'groupKey': 'sale/home/home-group',
#        'id': 'sale_home_servingware',
#        'name': 'Dinnerware',
#        'path': 'sale/home/servingware',
#        'selected': False,
#        'trackingInfo': {'metricCategoryID': 'SALE : HOME_SERVINGWARE',
#         'metricPageID': 'SALE : Home : Servingware',
#         'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZS9zZXJ2aW5nd2FyZTsjOyM7Izs'},
#        'type': 'REGULAR'}],
#      'count': 238,
#      'groupInfo': [{'displayState': 'EXPANDED',
#        'key': 'sale/home/home-group',
#        'sortOrder': 1}],
#      'groupKey': 'sale/online-areas',
#      'id': 'sale_home',
#      'name': 'HOME',
#      'path': 'sale/home',
#      'selected': False,
#      'trackingInfo': {'metricCategoryID': 'SALE : HOME',
#       'metricPageID': 'SALE : HOME',
#       'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7aG9tZTsjOyM7Izs'},
#      'type': 'REGULAR'}],
#    'count': 4842,
#    'groupInfo': [{'displayState': 'EXPANDED',
#      'key': 'sale/online-areas',
#      'sortOrder': 1}],
#    'groupKey': 'online-areas',
#    'id': 'sale',
#    'name': 'SALE',
#    'path': 'sale',
#    'selected': True,
#    'trackingInfo': {'metricCategoryID': 'Sale : View All',
#     'metricPageID': 'SALE_VIEWALL',
#     'ticketId': 'Oy9uYXZpZ2F0aW9uLXBhbmVsLXVzaW5nLWRwbi9jYXRlZ29yeS16b25lLXVzaW5nLWRwbi9jYXRlZ29yeS1zYWxlOyM7Y2F0ZWdvcnk7dl9uYXZpZ2F0aW9uX25vZGVfZW5fdXM7cm9vdDsjOyM7Izs'},
#    'type': 'REGULAR'}]}

# %%
#make a dictionary out of this.
headers = {
    'Origin':'http://www.hm.com',
    'Accept-Encoding'
}

# %% [markdown]
# ### What is the tag name and class name for the old price? The new price?

# %% [markdown]
# ### What is the tag name and class name for the link to the product page?

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# Use `requests`, not `urllib`.

# %% [markdown]
# ## Try to scrape the page: how many product names can you find?
#
# "Try" to do it, because it *will not work.* Once you've learned that it won't work, spend a few minutes **looking at the page code** to see if you can figure out why.
#
# Eventually, ask for help by writing on the board.

# %% [markdown]
# ## URLs

# %% [markdown]
# ### What is the URL for data about on-sale men's clothing?

# %% [markdown]
# ### What is the URL for data about on-sale women's clothing?

# %% [markdown]
# ### What is the URL for data about on-sale women's tops?

# %% [markdown]
# ### What changes about the url based on what you're looking for?

# %% [markdown]
# ## Request on-sale women's tops.
#
# ### How many results do you get?

# %% [markdown]
# ### How many total results are there? How do you change the URL to get more?
#
# There are a few ways to change the URL to: there is one very easy way and one a-little-difficult way.

# %% [markdown]
# ### Download all on-sale women's tops and save them to a CSV.
#
# I want this CSV to include
#
# - Name
# - Product code/number
# - Old price
# - On-sale price
# - Item's URL

# %% [markdown]
# ## Analyzing on-sale items
#
# ### Read in the on-sale CSV and make sure the data looks right

# %% [markdown]
# ### Convert the prices to numbers, if you haven't already

# %% [markdown]
# ### What is the average on-sale price of a women's top? Make a histogram, too, please.

# %% [markdown]
# ### What is the average discount between full price and on sale? Histogram too, please.

# %% [markdown]
# ### What is the average discount as a percentage of the full price? Histogram too, please.

# %% [markdown]
# ## Shopping the sales
#
# ### How many items are over 50% off?

# %% [markdown]
# ### Display all items above 50% off.
#
# Pandas doesn't want to show you every row. Change its settings so it will display up to **200 rows of content.**
