# %% [markdown]
# # A dataset about dogs.
#
# Data from [a FOIL request to New York City](https://www.muckrock.com/foi/new-york-city-17/pet-licensing-data-for-new-york-city-23826/)

# %% [markdown]
# ## MISC NOTES:
#
# **NaN** is missing data in pandas. anything with NaN in it you can do special things to.
# df['Animal Secondary Color'].str.lower()
# df.ABV.astype(float) !!! this won't work, because there are missing values that are written as ???
#
#
# you can't convert these '???' because they aren't NaN
# some data sets will have wierd values for missing things, like 999 = missing data.
# na_values=['???']
#
# **you can't convert things if there are missing values**
#
# ### pandas sort values:
# na_position = 'first' or na_position = 'last'
#
# get rid of nulls: careful, this potentially drops whole columns if you use it at the beginning
#
# .dropna()
#
# here if you just want to drop things that are IBUs
#
# df.dropna(subset=["IBUs"], inplace=True)

# %% [markdown]
# ## Do your importing and your setup

# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Read in the file `NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx` and look at the first five rows

# %%
df = pd.read_excel("NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx",na_values=['????','Unknown','UNKNOWN','unknown'])
df = df.head(30000)
df.head(30)
# Out:
#     Owner Zip Code            Animal Name Animal Gender  \
# 0            10024              BLUE MACK             M
# 1            10461           Indie Zephir             M
# 2            10013                  Bilal             M
# 3            10025                  Buddy             M
# 4            10013                    Ali             M
# 5            10013                  Queen             F
# 6            10035       Paige Sable Orta             F
# 7            10465                   Yogi             M
# 8            10013              Chewbacca             F
# 9            10013             IAN                    M
# 10           10028                   Lola             F
# 11           11232                 muneca             F
# 12           10022              Elizabeth             F
# 13           11209                 Benson             M
# 14           10025                 Dottie             F
# 15           11215          Lucy Moo Jung             F
# ...

# %% [markdown]
# ## How many rows do you have in the data? What are the column types?
#
# If there are more than 30,000 rows in your dataset, go back and only read in the first 30,000.

# %% [markdown]
# How do you limit the number of rows you're reading into the data frame?
#
# **firstlook at pd.read_csv? or pd.read_xlsx? to get an idea of what you can do!**
# >>you can resave file as a csv after you limit the number of rows using nrow = and use that new one, or you can use df=df.head(number of rows you want)

# %%
df.shape
# Out:
# (30000, 15)

# %%
df.dtypes
# Out:
# Owner Zip Code                     int64
# Animal Name                       object
# Animal Gender                     object
# Primary Breed                     object
# Secondary Breed                   object
# Animal Dominant Color             object
# Animal Secondary Color            object
# Animal Third Color                object
# Animal Birth              datetime64[ns]
# Spayed or Neut                    object
# Guard or Trained                  object
# Vaccinated                        object
# Application Date          datetime64[ns]
# License Issued Date       datetime64[ns]
# License Expired Date      datetime64[ns]
# dtype: object

# %% [markdown]
# **??How do you convert a string to a float??**
# >to convert a column into another type use:
#
# **df.column_name.astype(new type you want)**
#
# >>e.g. you have a float you want it to be an integer
# **df.IBUS_string.astype(integer)**
#
# NOTE: you have to save it back into the column!

# %% [markdown]
# ## Describe the dataset in words. What is each row? List two column titles along with what each of those columns means.
#
# For example: “Each row is an animal in the zoo. `is_reptile` is whether the animal is a reptile or not”

# %%
df.head()
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M                   NaN
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M                   NaN
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# ...

# %% [markdown]
# **Each row is a separate dog. Each column is a different piece of information about that particular dog.**

# %% [markdown]
# # Your thoughts
#
# Think of four questions you could ask this dataset. **Don't ask them**, just write them down in the cell below.

# %% [markdown]
# 1. What's the most common breed of dog?
# 2. How many licenses are expired?
# 3. How many dogs are not vaccinated?
# 4. Where do most dogs live (by zip code)?

# %% [markdown]
# # Looking at some dogs

# %% [markdown]
# ## What are the most popular (primary) breeds of dogs? Graph the top 10.

# %%
df['Primary Breed'].value_counts(ascending=False).head(10).plot(kind="barh")

# %% [markdown]
# How do you fix it so that the larger values are on top?
# ascending=True
# Tail(10)

# %%
df['Primary Breed'].value_counts(ascending=True).tail(10).plot(kind="barh")

# %% [markdown]
# ## "Unknown" is a terrible breed! Graph the top 10 breeds that are NOT Unknown

# %% [markdown]
# How do you leave certain values out of a dataset?
#
# You could consider unknown to be missing data.
# df_unknown = pd.read_excel("NYC_Dog_Licenses_Current_as_of_4-28-2016.xlsx",na_values=['????','Unknown'])
#
# Here's how you list every dog that's unknown:
#
# dogs_unknown = df[df['Primary Breed'] == 'Unknown'].head()
#
# And here's how you exclude unknowns:
#
# dogs_known = df[df['Primary Breed'] != 'Unknown'] **note the != means that are not**
#
# get me a value count of KNOWN dogs:
#
# without having save it in a variable first:
#
# df[df['Primary Breed'] != 'Unknown']['Primary Breed'].value_counts()
#
# after having saved it in a variable dogs_known:
#
# dogs_known['Primary Breed'].value_counts()
#
# HOW TO TEST FOR NaN:
# df[df['Primary Breed'].isnull()]
#
# HOW TO TEST FOR PRIMARY BREED NOT NULL:
# df[df['Primary Breed'].isnotnull()]
# This is saying: let's look for all the ones that have KNOWN primary breeds
#
# df['Primary Breed'].fillna("Unknown", inplace=True).head()
# This is FILLING ALL NA values in PRIMARY BREED with Unknown
# If you use inplace=True you don't have to resave it in another df

# %%
dogs_known = df[df['Primary Breed'] != 'Unknown'] 
dogs_known.head()
dogs_known['Primary Breed'].value_counts(ascending=True).tail(10).plot(kind="barh")

# %% [markdown]
# |(df['Primary Breed'] == 'Jack Russell Terrier')|
#
# Does the primary breed contain the word 'terrier'?
#
# you have to put df['column name'].str.contains('word you're looking for')
#
# **STRING CONTAINS**
#
# df['Primary Breed'].str.contains('Terrier').head()
#
# breeds = ['Yorkshire Terrier',"Jack Russell Terrier"]
# df.['Primary Breed'].isin(breeds)
#
# search for a string:
#
# when you do a str.contains you can get T, F or NaN
# but in df, it can only take T/F
# so if we only want secondary breed terrier dogs:
#
# **FILLING THINGS**
#
# get rid of na: na=False**:
#
# df['Secondary Breed'].str.contains('TER',na=False).head()

# %% [markdown]
# ## What are the most popular dog names?

# %% [markdown]
# ### how to count the number of rows that meet some condition:
# df[df.IBUs > 40].shape
# dataframe_name[dataframe_name.column {condition}].shape

# %%
df['Animal Name'].value_counts().head(5)
#we don't need to use dropna=True because we've already defined 'unknown' as an NA value in the beginning
#we could do this instead if we hadn't defined it: df['Animal Name'].value_counts(dropna=True).head(5)
# Out:
# Max        202
# Bella      193
# Charlie    172
# Lola       146
# Rocky      140
# Name: Animal Name, dtype: int64

# %% [markdown]
# ## Do any dogs have your name? How many dogs are named "Max," and how many are named "Maxwell"?

# %%
df[df['Animal Name'].str.contains('Kate',na=False)].head()
# Out:
#        Owner Zip Code Animal Name Animal Gender               Primary Breed  \
# 114             10463  Kate David             F                     Maltese
# 3098            10306        Kate             F                      Beagle
# 11311           10025        Kate             F  German Shepherd Crossbreed
# 16612           10038        Kate             F           Bull Dog, English
# 28922           11375        Kate             F                         NaN
#
#       Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 114               NaN                 White                    NaN
# 3098              NaN                 BLACK                  BROWN
# 11311             NaN                 BLACK                  BROWN
# 16612             NaN                   TAN                    RED
# 28922      Malti-Poo                  BLACK                    NaN
#
#       Animal Third Color Animal Birth Spayed or Neut Guard or Trained  \
# ...

# %%
df['Animal Name'].str.contains('Max',na=False).value_counts()
# Out:
# False    29623
# True       377
# Name: Animal Name, dtype: int64

# %%
df['Animal Name'].str.contains('Maxwell',na=False).value_counts()
# Out:
# False    29980
# True        20
# Name: Animal Name, dtype: int64

# %% [markdown]
# ## What percentage of dogs are guard dogs?
#
# Check out the documentation for [value counts](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html).

# %%
df['Guard or Trained'].str.contains('Yes',na=False).value_counts(normalize=True)*100
# Out:
# False    99.943333
# True      0.056667
# Name: Guard or Trained, dtype: float64

# %% [markdown]
# ## What are the actual numbers?

# %%
df['Guard or Trained'].str.contains('Yes',na=False).value_counts()
# Out:
# False    29983
# True        17
# Name: Guard or Trained, dtype: int64

# %% [markdown]
# ## Wait... if you add that up, is it the same as your number of rows? Where are the other dogs???? How can we find them??????
#
# Use your `.head()` to think about it, then you'll do some magic with `.value_counts()`

# %%
#I think we did this right!

# %% [markdown]
# ## Fill in all of those empty "Guard or Trained" columns with "No"
#
# Then check your result with another `.value_counts()`

# %%
df['Guard or Trained'].fillna("No",inplace=True)
df.head(5)
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M                   NaN
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M                   NaN
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# ...

# %%
df['Guard or Trained'].str.contains('No',na=False).value_counts()
# Out:
# True     29983
# False       17
# Name: Guard or Trained, dtype: int64

# %% [markdown]
# ## What are the top dog breeds for guard dogs?

# %%
#let's make a df with all the dogs that are guard dogs and call it 'guard'
guard_df = df[df['Guard or Trained'].str.contains('Yes',na=False)]
#you have to wrap the string in df [] otherwise it thinks it's a list/series!!
#let's look at our new df to check it
guard_df.head(5)
# Out:
#       Owner Zip Code                Animal Name Animal Gender  \
# 2363           10014                     Truman             M
# 2702           10014  Bojangles Swagu Rosenberg             M
# 2871           11361                    Dorofey             M
# 3065           10033                 CLARA                  F
# 3274           10301                        Mia             F
#
#             Primary Breed           Secondary Breed Animal Dominant Color  \
# 2363                  NaN  Chinese Crested/terrier                  WHITE
# 2702     Poodle, Standard                       NaN               Apricot
# 2871                  NaN     black russian terrier                 BLACK
# 3065                  NaN        American Fox Hound                 WHITE
# 3274  German Shepherd Dog                       NaN                 Black
#
#      Animal Secondary Color Animal Third Color Animal Birth Spayed or Neut  \
# ...

# %%
guard_df['Primary Breed'].value_counts()
# Out:
# German Shepherd Dog           3
# Doberman Pinscher             1
# Golden Retriever              1
# Schnauzer, Miniature          1
# Yorkshire Terrier             1
# Rottweiler                    1
# German Shepherd Crossbreed    1
# Poodle, Standard              1
# Shih Tzu                      1
# Labrador Retriever            1
# Name: Primary Breed, dtype: int64

# %% [markdown]
# ## How do you join data together? csv?
#
# # **MERGE**
#
# here are your two dataframes:
#
# df
# zipcodes_df
#
# what columns match?
#
# combined_df = df.merge(zipcodes_df, left_on='Owner Zip Code',right_on='zip')
# left_on = common column right_on = common column

# %% [markdown]
# ## Create a new column called "year" that is the dog's year of birth
#
# The `Animal Birth` column is a datetime, so you can get the year out of it with the code `df['Animal Birth'].apply(lambda birth: birth.year)`.

# %%
df['Year']= df['Animal Birth'].apply(lambda birth: birth.year)
df.head()
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M                   NaN
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M                   NaN
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# ...

# %% [markdown]
# ## Calculate a new column called “age” that shows approximately how old the dog is. How old are dogs on average?

# %%
df['Age']= 2017 - df['Year']
df.head(5)
# Out:
#    Owner Zip Code   Animal Name Animal Gender         Primary Breed  \
# 0           10024     BLUE MACK             M                   NaN
# 1           10461  Indie Zephir             M            Rottweiler
# 2           10013         Bilal             M  Australian Cattledog
# 3           10025         Buddy             M                   NaN
# 4           10013           Ali             M               Basenji
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1             NaN                 BLACK                    TAN
# 2             NaN                  Rust                    NaN
# 3        Cockapoo                 BLOND                  WHITE
# 4             NaN                 Black                    NaN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# 0                NaN   2007-11-01            Yes               No        Yes
# ...

# %%
df['Age'].mean()
# Out:
# 7.7124333333333333

# %% [markdown]
# # Joining data together

# %%
zipcodes_df = pd.read_csv('zipcodes-neighborhoods.csv')
zipcodes_df.head(3)
# Out:
#     neighborhood    zip borough
# 0  Central Bronx  10453   Bronx
# 1  Central Bronx  10457   Bronx
# 2  Central Bronx  10460   Bronx

# %% [markdown]
# ## Which neighborhood does each dog live in?
#
# You also have a (terrible) list of NYC neighborhoods in `zipcodes-neighborhoods.csv`. Join these two datasets together, so we know what neighborhood each dog lives in. **Be sure to not read it in as `df`, or else you'll overwrite your dogs dataframe.**

# %%
combined_df = df.merge(zipcodes_df, left_on = 'Owner Zip Code', right_on = 'zip')
combined_df.head(5)
# Out:
#    Owner Zip Code Animal Name Animal Gender                     Primary Breed  \
# 0           10024   BLUE MACK             M                               NaN
# 1           10024       Louie             M                               NaN
# 2           10024       Tosha             F               Collie, Smooth Coat
# 3           10024     Poppett             F  Dachshund, Long Haired Miniature
# 4           10024      Harlen             M                               NaN
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1       Coonhound                 Black                  White
# 2             NaN            BLUE MERLE                  WHITE
# 3             NaN                 Black                  Brown
# 4     Plott Hound                 BLACK                    TAN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# ...

# %% [markdown]
# ## What is the most popular dog name in all parts of the Bronx? How about Brooklyn? The Upper East Side?

# %%
#let's group by borough and find all of the names in the borough
combined_df.groupby('borough')['Animal Name'].value_counts().head()
# Out:
# borough  Animal Name
# Bronx    Bella          22
#          Max            21
#          Rocky          20
#          Lucky          15
#          Princess       15
# Name: Animal Name, dtype: int64

# %%
combined_df[combined_df['borough'].str.contains('Bronx')]['Animal Name'].value_counts().head(10)
# Out:
# Bella       22
# Max         21
# Rocky       20
# Princess    15
# Lucky       15
# Coco        14
# Luna        13
# Buddy       13
# Charlie     12
# Milo        11
# Name: Animal Name, dtype: int64

# %%
combined_df[combined_df['borough'].str.contains('Brooklyn')]['Animal Name'].value_counts().head(10)
# Out:
# Max                      46
# Bella                    45
# Charlie                  42
# Rocky                    36
# Lucy                     32
# Lucky                    32
# Princess                 29
# Lola                     27
# Dog Name Not Provided    26
# Teddy                    24
# Name: Animal Name, dtype: int64

# %%
combined_df[combined_df['borough'].str.contains('Upper East Side')]['Animal Name'].value_counts().head(10)
# Out:
# Series([], Name: Animal Name, dtype: int64)

# %% [markdown]
# ## What is the most common dog breed in each of the neighborhoods of NYC?

# %%
#access the df
#let's think this through. we need to group them by borough, and then for each of those groups find the value_counts for
#the primary breed. do we need to save each borough in a separate df? no that would be so tedious. 
common_breed_df = combined_df.groupby('borough')['Primary Breed'].value_counts().dropna()
common_breed_df.head(1)
#okay but how do we get it to display only the number one for each borough??
# combined_df[combined_df['borough'].str.contains('Bronx')]['Primary Breed'].value_counts().head(10)
# Out:
# borough  Primary Breed
# Bronx    Yorkshire Terrier    250
# Name: Primary Breed, dtype: int64

# %% [markdown]
# ## What breed of dogs are the least likely to be spayed? Male or female?

# %%
combined_df.head()
# Out:
#    Owner Zip Code Animal Name Animal Gender                     Primary Breed  \
# 0           10024   BLUE MACK             M                               NaN
# 1           10024       Louie             M                               NaN
# 2           10024       Tosha             F               Collie, Smooth Coat
# 3           10024     Poppett             F  Dachshund, Long Haired Miniature
# 4           10024      Harlen             M                               NaN
#
#   Secondary Breed Animal Dominant Color Animal Secondary Color  \
# 0   AIREDALE TERR                 BROWN                  BLACK
# 1       Coonhound                 Black                  White
# 2             NaN            BLUE MERLE                  WHITE
# 3             NaN                 Black                  Brown
# 4     Plott Hound                 BLACK                    TAN
#
#   Animal Third Color Animal Birth Spayed or Neut Guard or Trained Vaccinated  \
# ...

# %%
# 1. Find the number of dogs of each breed.
breed_df = combined_df['Primary Breed'].value_counts().dropna()
breed_df.astype(float).head()
#  df['Animal Secondary Color'].str.lower() df.ABV.astype(float)
# Out:
# Yorkshire Terrier     1861.0
# Shih Tzu              1739.0
# Chihuahua             1516.0
# Maltese               1116.0
# Labrador Retriever    1065.0
# Name: Primary Breed, dtype: float64

# %%
# 2. Find the number of dogs of each breed that are NOT fixed.
not_fixed_df = combined_df[combined_df['Spayed or Neut'].str.contains('No')]['Primary Breed'].value_counts().dropna().head(10)
not_fixed_df.astype(float).head()
# Out:
# Yorkshire Terrier                     531.0
# Shih Tzu                              401.0
# Chihuahua                             303.0
# Maltese                               300.0
# American Pit Bull Terrier/Pit Bull    173.0
# Name: Primary Breed, dtype: float64

# %%
# 3. Divide the second number by the first number, and then sort it.
not_fixed_df / breed_df
#I'm sort of confused and not sure if this is working or not. I think it is, but why are there NAs even though I've dropped
#them above?
# Out:
# Affenpinscher                                NaN
# Afghan Hound                                 NaN
# Airedale Terrier                             NaN
# Akita                                        NaN
# Akita Crossbreed                             NaN
# Alaskan Malamute                             NaN
# American Bully                               NaN
# American English Coonhound                   NaN
# American Eskimo dog                          NaN
# American Foxhound                            NaN
# American Pit Bull Mix / Pit Bull Mix         NaN
# American Pit Bull Terrier/Pit Bull      0.222938
# American Staffordshire Terrier               NaN
# Anatolian Shepherd Dog                       NaN
# Australian Cattle Dog                        NaN
# Australian Cattledog                         NaN
# Australian Kelpie                            NaN
# Australian Shepherd                          NaN
# Australian Silky Terrier                     NaN
# ...

# %% [markdown]
# ## Make a new column called monochrome that is True for any animal that only has black, white or grey as one of its colors. How many animals are monochrome?

# %%
#let's look at the colors first. do we want to do this as True or False? Meaning do we want to say where brown = true?
#only if there aren't too many options. but I think there will be lots of options. so let's see. woah so many.
combined_df.dropna(subset=['Animal Dominant Color'], inplace=True)
combined_df['Animal Dominant Color'].head(20)

# %%
combined_df['monochrome'] = combined_df['Animal Dominant Color'].str.contains('Black', 'Grey')
combined_df.head(100)

# combined_df[combined_df['borough'].str.contains('Brooklyn')]['Animal Name'].value_counts().head(10)

# %%
#okay, there are too many different colors to do a negative statement (I know these notes are probably confusing)
#but they make sense in my brain. So instead we'll do Animal Dominant Color = 'black' | 'white' | 'grey'

# %%
colors_df = combined_df[(combined_df['Animal Dominant Color']=='black') | (df['Animal Dominant Color']=='white') |(df['Animal Dominant Color']=='grey')]
colors_df.groupby('Animal')

# %%
df['GDP_millions'] = df['GDP_per_capita']*df['Population'] / 1000000
df.head()

combined_df['monochrome'] = combined_df['Animal Dominant Color']

# %% [markdown]
# ## How many dogs are in each borough? Plot it in a graph.

# %%
combined_df['borough'].value_counts().plot(kind='barh')

# %% [markdown]
# ## Which borough has the highest number of dogs per-capita?
#
# You’ll need to merge in `population_boro.csv`

# %%
pop_df = pd.read_csv("boro_population.csv",na_values=['????','Unknown','UNKNOWN','unknown'])
pop_df.head(10)
#first read it in and save it in a variable

# %%
pop_merge_df = pop_df.merge(combined_df, left_on='borough', right_on='borough')
pop_merge_df.head()
#merge it with the old combined_df. sooo much information now.

# %%
pop_merge_df.dtypes
#let's look at the data types, because we're going to have to divide population by the value counts for the borough,
#aka the number of unique dogs listed in each borough, to get the per capita.

# %%
pop_merge_df['borough'].value_counts()

# %%
#okay, to do this we need to divide the population of each borough by the number of dogs in each borough (which we can
#find using the value counts). each of these pieces of code works individually; why don't they work together?
dogs_per_capita = pop_merge_df['population'] / pop_merge_df['borough'].value_counts()

# %% [markdown]
# ## Make a bar graph of the top 5 breeds in each borough.
#
# How do you groupby and then only take the top X number? You **really** should ask me, because it's kind of crazy.

# %%
#to find the top 5 breeds...
pop_merge_df.groupby('borough')['Primary Breed'].value_counts().sort_values(ascending=False).dropna().head(5)

# %%
pop_merge_df.groupby('borough')['Primary Breed'].value_counts().sort_values(ascending=False).dropna().head(5).plot(kind='barh')

# %% [markdown]
# ## What percentage of dogs are not guard dogs?

# %%
df['Guard or Trained'].str.contains('No').value_counts(normalize=True, dropna=False) * 100

# %% [markdown]
# ## What are the most popular breeds of lady dogs vs boy dogs?
# ## notes:
# df['Primary Breed'].value_counts().head(3)
# **if you want to do something based on categories:**
#
# df.groupby('Animal Gender')['Primary Breed'].value_counts()
#
# watch for the ...
#
# it's saying: there's too much to display. so be careful with value_counts and groupby
#
# df.groupby('Animal Gender')['Primary Breed'].value_counts()
#
# ## use this!!
# ### groupby(level=0).nlargest(3).head(3)
# #### the whole thing is: df.groupby('Animal Gender')['Primary Breed'].value_counts().groupby(level=0).nlargest(3).head(3)

# %%
# df.groupby('Animal Gender')['Primary Breed'].value_counts().groupby(level=0).nlargest(3).head(3)
#These both work, but this one seems to work better...but is it leaving out values because I don't have the groupby(level=0)?
#I can't seem to add it and get it to work.
df.groupby('Animal Gender')['Primary Breed'].value_counts().sort_values(ascending=False).dropna().nlargest(3).head(5)
