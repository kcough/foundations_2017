# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/kaitlincough/Documents/Lede/soma/15-documents/marijuana/tabula-Muckrock_-_NYS_Marijuana_Possession_Arrests_by_County_2015-2017_YTD.csv')

# %%
df.head()
# Out:
#   Unnamed: 0                               Arrest Year Unnamed: 2 Unnamed: 3  \
# 0     County                         Top Arrest Charge       2015       2016
# 1     Albany  221.10 PL 221.10 CRIM POSS MARIJUANA-5TH         96         89
# 2        NaN  221.15 PL 221.15 CRIM POSS MARIJUANA-4TH         51         53
# 3        NaN  221.20 PL 221.20 CRIM POSS MARIJUANA-3RD         22         20
# 4        NaN  221.25 PL 221.25 CRIM POSS MARIJUANA-2ND         21         39
#
#   Unnamed: 4
# 0      2017*
# 1         70
# 2         46
# 3         14
# 4         12

# %%
df[df['Unnamed: 0'].str.contains(r'^\d', na=False)]
# Out:
#                                    Unnamed: 0 Arrest Year Unnamed: 2  \
# 50   221.15 PL 221.15 CRIM POSS MARIJUANA-4TH           2          1
# 51   221.20 PL 221.20 CRIM POSS MARIJUANA-3RD           0          1
# 52   221.25 PL 221.25 CRIM POSS MARIJUANA-2ND           3          2
# 53   221.30 PL 221.30 CRIM POSS MARIJUANA-1ST           0          0
# 55   221.10 PL 221.10 CRIM POSS MARIJUANA-5TH           6          8
# 56   221.15 PL 221.15 CRIM POSS MARIJUANA-4TH           7          7
# 57   221.20 PL 221.20 CRIM POSS MARIJUANA-3RD           3          1
# 58   221.25 PL 221.25 CRIM POSS MARIJUANA-2ND           3          5
# 59   221.30 PL 221.30 CRIM POSS MARIJUANA-1ST           3          0
# 111  221.15 PL 221.15 CRIM POSS MARIJUANA-4TH           2          2
# 112  221.20 PL 221.20 CRIM POSS MARIJUANA-3RD           0          2
# 113  221.25 PL 221.25 CRIM POSS MARIJUANA-2ND           1          2
# 114  221.30 PL 221.30 CRIM POSS MARIJUANA-1ST           0          0
# ...

# %%
df.loc[df['Unnamed:0'].str.contains(r'^\d', na=False), 'Unnamed:4*']=df['Unnamed:4']
df.loc[df['Unnamed:0'].str.contains(r'^\d', na=False), 'Unnamed:3*']=df['Unnamed:3']
df.loc[df['Unnamed:0'].str.contains(r'^\d', na=False), 'Unnamed:2*']=df['Top Arrest Charge']
df.loc[df['Unnamed:0'].str.contains(r'^\d', na=False), 'Top Arrest Charge']=df['Unnamed:0']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'Unnamed:4'
#
# During handling of the above exception, another exception occurred:
#
# ...
